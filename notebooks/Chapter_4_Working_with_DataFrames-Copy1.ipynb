# %% [markdown]
# <a id='menu'></a>
#  <hr style="width:100%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.25">
#
#  ![learning academy and data science campus logos](../images/la_dsc_logo.jpg)
#   <hr style="width:100%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.25">

# %% [markdown]
# <a id='menu'></a>
# # Introduction to Python
# ## Chapter 4 – Working with DataFrames
# ***
# Follow along with the code by running cells as you encounter them
# ***
# *Chapter Overview and Learning Objectives:*
# * [Packages and Datasets](#packages)
#
#
# * [Exploring Datasets](#exploring)
#     - Quick Previews
#     - Size
#     - Data Types
#     - Column Names
#
#
# * [Sorting Data](#sorting)
#
#
# * [Subsetting Data](#subsetting)
#     - Selecting Single Columns
#     - Selecting Multiple Columns
#
#
# * [Filtering](#filter)
#     - Single Conditional Filtering
#     - Multiple Conditional Filtering
#
#
# * [Deriving New Columns](#new_columns)
#     - Constant Values
#     - Numeric Values
#     - Boolean and Binary Values
#     - Mapping new values
#     - Deleting columns
#
#
# * [Merging Data](#merge)
#     - About Merging
#     - Merging using Pandas
#     - Union joins

# %% [markdown]
# <a id='packages'></a>
# <hr style="width:100%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:1">

# %% [markdown]
# ## Packages and Datasets

# %% [markdown]
# ### Packages
# As a reminder – we should always import our packages at the top of our script.
#
#
# In this session we will use `pandas`, and give it the nickname `pd`.

# %%
# Import Pandas in this Cell
import pandas as pd

# %% [markdown]
# You can run the "solution" cell if you need help - or revisit chapter 2.

# %%
# Solution - These cells contain answers for the exercises.
# Run once to reveal the code
# Run again to reveal the output

# %load ../solutions/chapter_4/importpandas.py

# %% [markdown]
# ### Datasets
# Good practice should also be to import our datasets at the top of our script too.
#
# In this session we’ll be using:
#
#
# | variable name | file name  |
# | --- | --- |
# | animals | animals.csv |
# | titanic | titanic.xlsx |
# | joining_data1 | joining_data1.csv |
# | joining_data2 | joining_data2.csv |
# | union_join_data | union_data.csv |
# | marvel_left | joining_exercise1.csv |
# | marvel_right | joining_exercise2.csv |
#
#
#
# These are all straight forward data imports with no additional parameters.
#
# Use the cell below to load in these datasets.
#
# If you are stuck use the solution cell; remember practicing simple commands is important for retaining the skills you’re learning.

# %%
# Import your datasets here

# %%
# %load ../solutions/chapter_4/chapter_four_data.py
# load in the datasets

animals = pd.read_csv(filepath_or_buffer = "../data/animals.csv")
titanic = pd.read_excel(io = "../data/titanic.xlsx")
joining_data1 = pd.read_csv("../data/joining_data1.csv")
joining_data2 = pd.read_csv("../data/joining_data2.csv")
union_join_data = pd.read_csv("../data/union_data.csv")
marvel_left = pd.read_csv("../data/joining_exercise1.csv")
marvel_right = pd.read_csv("../data/joining_exercise2.csv")

# %% [markdown]
# You can check your variables are loaded by using `%whos` in Jupyter. In Spyder or other IDE's they should appear in your variable explorer.
#
# If you struggle with this section – review chapter 3 – Reading In and Exporting Data

# %%
# %whos
# Out:
# Variable          Type         Data/Info
# ----------------------------------------
# animals           DataFrame           IncidentNumber    <...>n[5752 rows x 19 columns]
# joining_data1     DataFrame                  name animal<...>    Arf Vader    dog    6
# joining_data2     DataFrame                  name  vacci<...>    Spiderpig        True
# marvel_left       DataFrame                             <...>uly             622648074
# marvel_right      DataFrame                             <...>Home          2019     90
# pd                module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# titanic           DataFrame          pclass  survived   <...>n[1309 rows x 14 columns]
# union_join_data   DataFrame               name    animal<...>   Repecka   chicken    1

# %% [markdown]
# [return to menu](#menu)

# %%
pd.crosstab(index = titanic["survived"], columns = titanic["sex"])
# Out:
# sex       female  male
# survived
# 0            127   682
# 1            339   161

# %%
def crosstab_percentages(dataframe, rowval, colval):
    test = []
    test = pd.crosstab(index = dataframe[rowval], columns = dataframe[colval]).apply(lambda r: (r/r.sum()*100), axis=0)\
                .append(test.sum(numeric_only=True), ignore_index=True)
    return test

# %%
a = pd.crosstab(index = titanic["survived"], columns = titanic["sex"]).apply(lambda r: (r/r.sum()*100), axis=0)

a = a.append(a.sum(numeric_only=True), ignore_index=True)
    
a.sample()
# Out:
# sex      female        male
# 0     27.253219   80.901542
# 1     72.746781   19.098458
# 2    100.000000  100.000000

# %%
titanic[1:10]
# Out:
#    pclass  survived                                             name     sex  \
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked  \
# 1   0.9167      1      2    113781  151.5500  C22 C26        S
# 2   2.0000      1      2    113781  151.5500  C22 C26        S
# 3  30.0000      1      2    113781  151.5500  C22 C26        S
# 4  25.0000      1      2    113781  151.5500  C22 C26        S
# 5  48.0000      0      0     19952   26.5500      E12        S
# 6  63.0000      1      0     13502   77.9583       D7        S
# 7  39.0000      0      0    112050    0.0000      A36        S
# 8  53.0000      2      0     11769   51.4792     C101        S
# 9  71.0000      0      0  PC 17609   49.5042      NaN        C
#
#                          home.dest   body boat
# 1  Montreal, PQ / Chesterville, ON    NaN   11
# 2  Montreal, PQ / Chesterville, ON    NaN  NaN
# 3  Montreal, PQ / Chesterville, ON  135.0  NaN
# 4  Montreal, PQ / Chesterville, ON    NaN  NaN
# 5                     New York, NY    NaN    3
# 6                       Hudson, NY    NaN   10
# 7                      Belfast, NI    NaN  NaN
# 8              Bayside, Queens, NY    NaN    D
# 9              Montevideo, Uruguay   22.0  NaN

# %%
a = pd.crosstab(index = titanic["survived"], columns = titanic["sex"]).apply(lambda r: (r/r.sum()*100), axis=0)

b = a.append(a.sum(numeric_only=True), ignore_index=True)
    
a
# Out:
# sex      female        male
# 0     27.253219   80.901542
# 1     72.746781   19.098458
# 2    100.000000  100.000000

# %%
a
# Out:
# sex          female       male
# survived
# 0         27.253219  80.901542
# 1         72.746781  19.098458

# %%
del(test)

# %%
pd.crosstab(index = titanic["survived"], columns = titanic["sex"],
            normalize = "columns",
            margins = True)
# Out:
# sex         female      male       All
# survived
# 0         0.272532  0.809015  0.618029
# 1         0.727468  0.190985  0.381971

# %%
test.append(test.sum(numeric_only=True), ignore_index=True)
# Out:
# sex    female      male
# 0    0.272532  0.809015
# 1    0.727468  0.190985
# 2    1.000000  1.000000

# %%
test
# Out:
# sex       female  male
# survived
# 0            127   682
# 1            339   161

# %% [markdown]
# <a id='exploring'></a>
# <hr style="width:100%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:1">

# %% [markdown]
# ## Exploring Datasets

# %% [markdown]
# Before you start working with a dataset it can be important to examine it. For example:
#
# * Do the values look how you would expect?
# * Does the data have the right number of rows and columns?
# * Do the columns have your expected data types?
# * Is your data [clean?](https://en.wikipedia.org/wiki/Data_cleansing)
#
# In this section we’ll look at various ways of exploring our data.
#
# In chapter 5 we will look at how we can clean our data. When working with data, cleaning is normally a step we’d do first. Those concepts are a little more complicated; and we like to establish a good base knowledge of how Python works first. For these sessions we’ll be using data that has already been cleaned to make it easy to handle.

# %% [markdown]
# ### Quick Previews

# %% [markdown]
# In the last section we looked at three methods of quickly inspecting our dataframes.
#
# * `.head()`  - Top 5 rows
# * `.tail()`  - Bottom 5 Rows
# * `.sample()` - 1 Randomly sampled row.
#
# We use these because we do not always want Jupyter Notebooks to print out large datasets; we just want to check that certain operations have worked on a smaller amount of data.
#
# We can modify how many rows are returned by putting a number within the round brackets.
#
# The number in the round brackets is known as an argument. `.head()` and `.tail()` have a default argument of 5; if we don't pass an argument that default behaviour is used.
#
# e.g.

# %%
animals.head(3)
# Out:
#   IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0         139091  01/01/2009 03:01     2009  2008/09  Special Service
# 1         275091  01/01/2009 08:51     2009  2008/09  Special Service
# 2        2075091  04/01/2009 10:07     2009  2008/09  Special Service
#
#    PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 0        1.0             2.0                   255                   510.0
# 1        1.0             1.0                   255                   255.0
# 2        1.0             1.0                   255                   255.0
#
#                             FinalDescription AnimalGroupParent  \
# 0  DOG WITH JAW TRAPPED IN MAGAZINE RACK,B15               Dog
# 1          ASSIST RSPCA WITH FOX TRAPPED,B15               Fox
# 2                    DOG CAUGHT IN DRAIN,B15               Dog
#
#                 PropertyType       SpecialServiceTypeCategory  \
# 0  House - single occupancy           Other animal assistance
# 1                   Railings          Other animal assistance
# 2             Pipe or drain   Animal rescue from below ground
#
#                                   SpecialServiceType  Borough StnGroundName  \
# 0  Animal assistance involving livestock - Other ...  Croydon       Norbury
# 1  Animal assistance involving livestock - Other ...  Croydon      Woodside
# 2     Animal rescue from below ground - Domestic pet   Sutton    Wallington
#
#   AnimalClass  Code        London
# 0      Mammal  00AH  Outer London
# 1      Mammal  00AH  Outer London
# 2      Mammal  00BF  Outer London

# %% [markdown]
# Here I am using the `.head()` method to just display the top 3 rows of my DataFrame.
#
# This modifies the default behaviour of `.head()` by displaying just 3 rows instead of 5.

# %% [markdown]
# If you run just
#
# `animals`
#
# You may notice that Jupyter does not display all of the rows in our DataFrame.
#
# ![hidden rows](../images/sort_missing_rows.PNG)
#
# Instead it represents these rows using the  `…` (ellipsis) symbol.
#
# You may also see this with columns. This happens in large datasets; and helps to save computational power. This is similar to the max print option in Spyder.
#
# While there are various ways of changing this setting with Jupyter (Stack Overflow has several answers) if you are regularly using large DataFrames, and wish to inspect all rows you may wish to the the `Spyder IDE`. This has an inbuilt data viewer.

# %% [markdown]
# We can also use `.info()` this gives us information about:
#
# * The class of the object – a `pandas` DataFrame
# * The range (or length of our index) – our number of rows
# * How many columns we have
# * The column names
# * The number of non-null entries (a.k.a without missing values)
# * The data type of the column
# * The number of columns of each data type.
#
# We’ll look at data types in more detail later.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# home.dest    745 non-null object
# body         121 non-null float64
# boat         486 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.2+ KB

# %% [markdown]
# <hr style="width:70%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Size

# %% [markdown]
# Knowing the size of our DataFrame is also useful – we can achieve this in a few ways.

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5752 entries, 0 to 5751
# Data columns (total 19 columns):
# IncidentNumber                5752 non-null object
# DateTimeOfCall                5752 non-null object
# CalYear                       5752 non-null int64
# FinYear                       5752 non-null object
# TypeOfIncident                5752 non-null object
# PumpCount                     5716 non-null float64
# PumpHoursTotal                5716 non-null float64
# HourlyNominalCost(£)          5752 non-null int64
# IncidentNominalCost(£)        5716 non-null float64
# FinalDescription              5749 non-null object
# AnimalGroupParent             5752 non-null object
# PropertyType                  5752 non-null object
# SpecialServiceTypeCategory    5752 non-null object
# SpecialServiceType            5752 non-null object
# Borough                       5748 non-null object
# StnGroundName                 5752 non-null object
# AnimalClass                   5752 non-null object
# Code                          5742 non-null object
# London                        5742 non-null object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 853.9+ KB

# %%
animals.shape
# Out:
# (5752, 19)

# %% [markdown]
# `.shape` provides us with the dimensions of the object.
#
# Notice this is an attribute of the DataFrame rather than a method – it describes the shape of animals - and so does not use round brackets at the end.
#
# We talk a bit more about the similarities and differences between functions, methods and attributes in chapter 2. Feel free to review that section if you are stuck.

# %% [markdown]
# We can use our indexing brackets to return an item in this tuple – for example the number rows at index 0.

# %%
animals.shape[0]
# Out:
# 5752

# %% [markdown]
# And the number of columns at index 1.

# %%
animals.shape[1]
# Out:
# 19

# %% [markdown]
# As an aside:
#
# Because `.shape` returns us a tuple we can assign each of these to it’s own variable.
#
# To do this we give our variable names in the order of the tuple output, separated by a comma before our assignment operator (=).
#
# Our tuple outputs rows first then columns, so we give our variables as `nrow` and `ncol`.
#
# You can see that we can then use these in the print statement below.

# %%
nrow, ncol = animals.shape

print("There are", nrow, "rows, and", ncol, "columns in the animals DataFrame")
# Out:
# There are 5752 rows, and 19 columns in the animals DataFrame

# %% [markdown]
# This is the same code as below – but in one line.

# %%
# This is the same as nrow, ncol = animals.shape

nrow = animals.shape[0]
ncol = animals.shape[1]

# %% [markdown]
# We can also use the inbuilt `len()` function to find the **len**gth. This will return us the rows.

# %%
len(animals)
# Out:
# 5752

# %% [markdown]
# We can also modify this to return us the number of columns – like so.

# %%
animals.columns
# Out:
# Index(['IncidentNumber', 'DateTimeOfCall', 'CalYear', 'FinYear',
#        'TypeOfIncident', 'PumpCount', 'PumpHoursTotal', 'HourlyNominalCost(£)',
#        'IncidentNominalCost(£)', 'FinalDescription', 'AnimalGroupParent',
#        'PropertyType', 'SpecialServiceTypeCategory', 'SpecialServiceType',
#        'Borough', 'StnGroundName', 'AnimalClass', 'Code', 'London'],
#       dtype='object')

# %%
len(animals.columns)
# Out:
# 19

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise
#
# Look at the dimensions of the `titanic` DataFrame.
#
# Use shape, then try returning the columns and rows individually.

# %%
# Exercise

titanic.shape[1]
titanic.shape[0]
# Out:
# 1309

# %%
# %load ../solutions/chapter_4/titanic_shape.py
#Look at the dimensions of the `titanic` DataFrame.

print(titanic.shape) # returns rows, columns
print(len(titanic)) # retuns rows
print(len(titanic.columns)) # returns columns
# Out:
# (1309, 14)
# 1309
# 14

# %% [markdown]
# If you run the solution cell you’ll notice that the answers are within a print function.
#
# Remember that Jupyter Notebooks prints out the last output in a cell unless we do this.
#
# See Chapter 2 for a refresher on this.

# %% [markdown]
# <hr style="width:70%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Data Types

# %% [markdown]
# It is also important to check the data types when we bring in data. If you’ve worked with other analytical software before you’ll know that sometimes data doesn’t come in as we would expect.
#
# We do this using `.dtypes`

# %%
animals.dtypes
# Out:
# IncidentNumber                 object
# DateTimeOfCall                 object
# CalYear                         int64
# FinYear                        object
# TypeOfIncident                 object
# PumpCount                     float64
# PumpHoursTotal                float64
# HourlyNominalCost(£)            int64
# IncidentNominalCost(£)        float64
# FinalDescription               object
# AnimalGroupParent              object
# PropertyType                   object
# SpecialServiceTypeCategory     object
# SpecialServiceType             object
# Borough                        object
# StnGroundName                  object
# AnimalClass                    object
# Code                           object
# London                         object
# dtype: object

# %% [markdown]
# We have some of the data types we’re seen before
#
# * **int** represents integers; our whole numbers
# 	* CalYear (Calendar Year) is column of whole numbers
#
#
# * **float** represents ‘floating point’ numbers or decimals
# 	* IncidentNominalCost(£) (The financial cost of each incident) is a decimal number.
#
#
# * **object** or **O**  here represents what we’ve been calling *string* data so far - text values
# 	* AnimalClass (The kind of animal) is a text based value.
#
# We may also see
#
# * **bool** - representing Boolean values; our True and False
# * **datetime** - date and time values
# * **category** - a special `pandas` datatype for categorical or factor variables.

# %%
animals['DateTimeOfCall'].dtypes

# This is how we select a single column; we'll cover this later
# Out:
# dtype('O')

# %% [markdown]
# You may notice that some categories have not come in quite how we would expect.
#
# `DateTimeOfCall` has come in as an `object` or text value; when it should be `datetime`.
#
# This is extremely common with dates and times in a variety of software; not just Python!
#
# ![xkcd_date_times](../images/iso_8601.png)
#
# Python will often choose an `object` data type for columns; if there’s any ambiguity over the data type.
#
# This is because this data type retains all the characteristics of the data – and allows us to make the choice about how to process it.
#
# For example - 01/11/19 could be interpreted as either 1st November 2019,  the 11th January 2019 or even the 19th November 2001 - depending on region.
#
# We don’t look at handling date and time data in this course; we’ll leave these columns alone for now.
#
# [Here]( https://www.geeksforgeeks.org/python-working-with-date-and-time-using-pandas/) is a tutorial for handling dates and times using `pandas`.

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise
#
# Look at the data types of the `titanic` DataFrame.
#
# Are there any values you didn't expect to see?
#
# You can check the Data Dictionary (an explanation of each column) [here](https://www.kaggle.com/c/titanic/data)
#
# Check the soloution for more information.

# %%
titanic["bool_surv"] = titanic["survived"].astype("bool")
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000      0      0   24160  211.3375       B5        S
# 1   0.9167      1      2  113781  151.5500  C22 C26        S
# 2   2.0000      1      2  113781  151.5500  C22 C26        S
# 3  30.0000      1      2  113781  151.5500  C22 C26        S
# 4  25.0000      1      2  113781  151.5500  C22 C26        S
#
#                          home.dest   body boat  bool_surv
# 0                     St Louis, MO    NaN    2       True
# 1  Montreal, PQ / Chesterville, ON    NaN   11       True
# 2  Montreal, PQ / Chesterville, ON    NaN  NaN      False
# 3  Montreal, PQ / Chesterville, ON  135.0  NaN      False
# 4  Montreal, PQ / Chesterville, ON    NaN  NaN      False

# %%
# Exercise

# %%
# %load ../solutions/chapter_4/titanic_dtypes.py
# Look at the data types of the titanic DataFrame.

titanic.dtypes

#  We may expect "survived" to be a boolean - but it's a numeric 
# It would need to be TRUE or FALSE or True or False in our Dataset to
# come over as a boolean.

# # We may expect "boat" to be a number - but some boats are referred to by letters.
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# home.dest     object
# body         float64
# boat          object
# bool_surv       bool
# dtype: object

# %% [markdown]
# <hr style="width:70%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Column Names

# %% [markdown]
# It is important to know what your columns are called because in Python we commonly select our columns by name.
#
# First we give the DataFrame name then the name of our column, in quotes, inside square brackets.
#
# ``` python
# animals['AnimalClass']
# ```
#
# We can then add a method to the end – e.g `.head()`
#
# e.g.

# %%
animals.head()
# Out:
#   IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0         139091  01/01/2009 03:01     2009  2008/09  Special Service
# 1         275091  01/01/2009 08:51     2009  2008/09  Special Service
# 2        2075091  04/01/2009 10:07     2009  2008/09  Special Service
# 3        2872091  05/01/2009 12:27     2009  2008/09  Special Service
# 4        3553091  06/01/2009 15:23     2009  2008/09  Special Service
#
#    PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 0        1.0             2.0                   255                   510.0
# 1        1.0             1.0                   255                   255.0
# 2        1.0             1.0                   255                   255.0
# 3        1.0             1.0                   255                   255.0
# 4        1.0             1.0                   255                   255.0
#
#                             FinalDescription AnimalGroupParent  \
# 0  DOG WITH JAW TRAPPED IN MAGAZINE RACK,B15               Dog
# 1          ASSIST RSPCA WITH FOX TRAPPED,B15               Fox
# 2                    DOG CAUGHT IN DRAIN,B15               Dog
# 3                  HORSE TRAPPED IN LAKE,J17             Horse
# 4              RABBIT TRAPPED UNDER SOFA,B15            Rabbit
#
#                                     PropertyType  \
# 0                      House - single occupancy
# 1                                       Railings
# 2                                 Pipe or drain
# 3  Intensive Farming Sheds (chickens, pigs etc)
# 4                      House - single occupancy
#
#         SpecialServiceTypeCategory  \
# 0          Other animal assistance
# 1          Other animal assistance
# 2  Animal rescue from below ground
# 3         Animal rescue from water
# 4          Other animal assistance
#
#                                   SpecialServiceType     Borough  \
# 0  Animal assistance involving livestock - Other ...     Croydon
# 1  Animal assistance involving livestock - Other ...     Croydon
# 2     Animal rescue from below ground - Domestic pet      Sutton
# 3             Animal rescue from water - Farm animal  Hillingdon
# 4  Animal assistance involving livestock - Other ...    Havering
#
#   StnGroundName AnimalClass  Code        London
# 0       Norbury      Mammal  00AH  Outer London
# 1      Woodside      Mammal  00AH  Outer London
# 2    Wallington      Mammal  00BF  Outer London
# 3       Ruislip      Mammal  00AS  Outer London
# 4   Harold Hill      Mammal  00AR  Outer London

# %%
animals['AnimalClass'].head()
# Out:
# 0    Mammal
# 1    Mammal
# 2    Mammal
# 3    Mammal
# 4    Mammal
# Name: AnimalClass, dtype: object

# %% [markdown]
# While Python can handle column names with spaces, symbols and irregular capitalisation; it is often easier to clean them.
#
# We’ll have a look at how can do this in Chapter 5.
#
# We can access our columns by using the `.columns` attribute - remember no brackets after attributes.
#
# This will print out our columns as a data type called an `index`.

# %%
animals.columns
# Out:
# Index(['IncidentNumber', 'DateTimeOfCall', 'CalYear', 'FinYear',
#        'TypeOfIncident', 'PumpCount', 'PumpHoursTotal', 'HourlyNominalCost(£)',
#        'IncidentNominalCost(£)', 'FinalDescription', 'AnimalGroupParent',
#        'PropertyType', 'SpecialServiceTypeCategory', 'SpecialServiceType',
#        'Borough', 'StnGroundName', 'AnimalClass', 'Code', 'London'],
#       dtype='object')

# %% [markdown]
# I’d like to display them as a list – so I add (or **chain**) the method `.tolist()` on the end.

# %%
animals.columns.tolist()
# Out:
# ['IncidentNumber',
#  'DateTimeOfCall',
#  'CalYear',
#  'FinYear',
#  'TypeOfIncident',
#  'PumpCount',
#  'PumpHoursTotal',
#  'HourlyNominalCost(£)',
#  'IncidentNominalCost(£)',
#  'FinalDescription',
#  'AnimalGroupParent',
#  'PropertyType',
#  'SpecialServiceTypeCategory',
#  'SpecialServiceType',
#  'Borough',
#  'StnGroundName',
#  'AnimalClass',
#  'Code',
#  'London']

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise
#
# Look at the column names of the `titanic` DataFrame.

# %%
# Exercise

titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'home.dest', 'body', 'boat', 'bool_surv'],
#       dtype='object')

# %%
# Solution - These cells contain answers for the exercises.
# Run once to reveal the code
# Run again to reveal the output

# %load ../solutions/chapter_4/titanic_columns.py

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# We can also use Jupyter’s auto complete feature to help us when accessing the names of our columns.
#
# In the cell below place your cursor after the H and hit tab.

# %%
animals['HourlyNominalCost(£)'].head()
# Out:
# 0    255
# 1    255
# 2    255
# 3    255
# 4    255
# Name: HourlyNominalCost(£), dtype: int64

# %% [markdown]
# You’ll see that the auto complete option gives us the name of our `HourlyNominalCost(£)` column.
#
# This can be a really useful shortcut when we’re writing our code – rather than typing out full column names.

# %% [markdown]
# [return to menu](#menu)

# %% [markdown]
# <a id='sorting'></a>
# <hr style="width:100%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:1">

# %% [markdown]
# ## Sorting Data

# %% [markdown]
# Our data is displayed in the same order as the source data.
#
# We may want to sort our data, based on specific columns.
#
# To do this we use the method `.sort_values(by="column name")`

# %%
animals_sorted = animals.sort_values(by="IncidentNominalCost(£)")

animals_sorted.head(20)
# Out:
#     IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 122       52735091  31/03/2009 07:40     2009  2008/09  Special Service
# 88        36729091  04/03/2009 23:35     2009  2008/09  Special Service
# 86        36590091  04/03/2009 18:36     2009  2008/09  Special Service
# 85        35781091  03/03/2009 12:54     2009  2008/09  Special Service
# 84        35738091  03/03/2009 11:05     2009  2008/09  Special Service
# 83        35246091  02/03/2009 14:29     2009  2008/09  Special Service
# 82        34598091  01/03/2009 08:31     2009  2008/09  Special Service
# 81        33526091  27/02/2009 16:35     2009  2008/09  Special Service
# 79        31317091  23/02/2009 16:56     2009  2008/09  Special Service
# 78          169092  23/02/2009 15:28     2009  2008/09  Special Service
# 77        30981091  22/02/2009 17:22     2009  2008/09  Special Service
# 76        30836091  22/02/2009 13:17     2009  2008/09  Special Service
# 75        30194091  21/02/2009 16:12     2009  2008/09  Special Service
# 74        30133091  21/02/2009 14:08     2009  2008/09  Special Service
# 73        29403091  20/02/2009 09:35     2009  2008/09  Special Service
# 72        28382091  18/02/2009 13:22     2009  2008/09  Special Service
# 71        27898091  17/02/2009 16:13     2009  2008/09  Special Service
# 69        27109091  16/02/2009 11:13     2009  2008/09  Special Service
# 68        26715091  15/02/2009 15:53     2009  2008/09  Special Service
# 67        26040091  14/02/2009 11:38     2009  2008/09  Special Service
#
#      PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 122        1.0             1.0                   255                   255.0
# 88         1.0             1.0                   255                   255.0
# 86         1.0             1.0                   255                   255.0
# 85         1.0             1.0                   255                   255.0
# 84         1.0             1.0                   255                   255.0
# 83         1.0             1.0                   255                   255.0
# 82         1.0             1.0                   255                   255.0
# 81         1.0             1.0                   255                   255.0
# 79         1.0             1.0                   255                   255.0
# 78         1.0             1.0                   255                   255.0
# 77         1.0             1.0                   255                   255.0
# 76         1.0             1.0                   255                   255.0
# 75         1.0             1.0                   255                   255.0
# 74         1.0             1.0                   255                   255.0
# 73         1.0             1.0                   255                   255.0
# 72         1.0             1.0                   255                   255.0
# 71         1.0             1.0                   255                   255.0
# 69         1.0             1.0                   255                   255.0
# 68         1.0             1.0                   255                   255.0
# 67         1.0             1.0                   255                   255.0
#
#                                       FinalDescription  \
# 122                      CAT TRAPPED BETWEEN WALLS,B15
# 88                          DOG TRAPPED IN STREAM, B15
# 86                            DOG TRAPPED IN WATER,J15
# 85                      PIGEON TRAPPED IN SHELTER, B15
# 84               CAT TRAPPED BETWEEN CHIMNEY POTS, B15
# 83             CAT TRAPPED IN NARROW TUBE ON ROOF, B15
# 82                           DOG TRAPPED UNDER CAR,B15
# 81                          BIRD TRAPPED IN WIRING,B15
# 79                  BIRD TRAPPED IN APEX OF HOUSE, B15
# 78      KITTEN TRAPPED BETWEEN WALL AND WOOD PANEL,B15
# 77                             SMALL ANIMAL RESCUE,B15
# 76   TO ASSIST RSPCA WITH GULL IN TREE TRAPPED BY F...
# 75                   ASSIST RSPCA WITH CAT IN TREE,B15
# 74                        FOX TRAPPED ABOVE WATER, B15
# 73                             INJURED CAT ON ROOF,B15
# 72          ASSIST RSPCA WITH GULL STUCK IN TREE  ,B15
# 71                                  PIGEON TRAPPED,B15
# 69              ASSIST RSPCA WITH TRAPPED PIGEON , B15
# 68                               SWAN IN DISTRESS, J15
# 67                      DOG TRAPPED IN BARBED WIRE,B15
#
#                     AnimalGroupParent  \
# 122                               Cat
# 88                                Dog
# 86                                Dog
# 85                               Bird
# 84                                Cat
# 83                                Cat
# 82                                Dog
# 81                               Bird
# 79                               Bird
# 78                                Cat
# 77   Unknown - Domestic Animal Or Pet
# 76                               Bird
# 75                                Cat
# 74                                Fox
# 73                                Cat
# 72                               Bird
# 71                               Bird
# 69                               Bird
# 68                               Bird
# 67                                Dog
#
#                                           PropertyType  \
# 122                               Takeaway, fast food
# 88                         Canal/riverbank vegetation
# 86                                        River/canal
# 85                            Railway building - other
# 84                           House - single occupancy
# 83                           House - single occupancy
# 82                                                Car
# 81                           House - single occupancy
# 79                           House - single occupancy
# 78   Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 77                           House - single occupancy
# 76                                Lake/pond/reservoir
# 75                                         Tree scrub
# 74                                              Bridge
# 73   Purpose Built Flats/Maisonettes - 10 or more s...
# 72                                               Park
# 71                                         Tree scrub
# 69                                        Single shop
# 68                                        River/canal
# 67               Cycle path/public footpath/bridleway
#
#           SpecialServiceTypeCategory  \
# 122          Other animal assistance
# 88          Animal rescue from water
# 86          Animal rescue from water
# 85         Animal rescue from height
# 84         Animal rescue from height
# 83         Animal rescue from height
# 82           Other animal assistance
# 81         Animal rescue from height
# 79         Animal rescue from height
# 78   Animal rescue from below ground
# 77         Animal rescue from height
# 76          Animal rescue from water
# 75   Animal rescue from below ground
# 74         Animal rescue from height
# 73         Animal rescue from height
# 72   Animal rescue from below ground
# 71         Animal rescue from height
# 69         Animal rescue from height
# 68          Animal rescue from water
# 67           Other animal assistance
#
#                                     SpecialServiceType               Borough  \
# 122  Animal assistance involving livestock - Other ...               Bromley
# 88             Animal rescue from water - Domestic pet              Lewisham
# 86                Wild animal rescue from water or mud                Merton
# 85                    Animal rescue from height - Bird                Newham
# 84            Animal rescue from height - Domestic pet                Newham
# 83            Animal rescue from height - Domestic pet                Newham
# 82   Animal assistance involving livestock - Other ...                Camden
# 81                    Animal rescue from height - Bird  Barking And Dagenham
# 79                    Animal rescue from height - Bird        Waltham Forest
# 78      Animal rescue from below ground - Domestic pet                Newham
# 77            Animal rescue from height - Domestic pet              Lewisham
# 76                     Animal rescue from water - Bird                Merton
# 75      Animal rescue from below ground - Domestic pet                Barnet
# 74                      Wild animal rescue from height               Lambeth
# 73            Animal rescue from height - Domestic pet  Barking And Dagenham
# 72              Animal rescue from below ground - Bird                 Brent
# 71                    Animal rescue from height - Bird              Hounslow
# 69                    Animal rescue from height - Bird               Croydon
# 68                     Animal rescue from water - Bird         Tower Hamlets
# 67   Animal assistance involving livestock - Other ...              Haringey
#
#     StnGroundName AnimalClass  Code        London
# 122   Biggin Hill      Mammal  00AF  Outer London
# 88      Lee Green      Mammal  00AZ  Inner London
# 86      Wimbledon      Mammal  00BA  Inner London
# 85       Plaistow        Bird  00BB  Outer London
# 84       East Ham      Mammal  00BB  Inner London
# 83       East Ham      Mammal  00BB  Inner London
# 82         Euston      Mammal  00AG  Inner London
# 81        Barking        Bird  00AB  Inner London
# 79       Woodford        Bird  00BH  Outer London
# 78      Stratford      Mammal  00BB  Outer London
# 77        Bromley      Mammal  00AZ  Inner London
# 76     New Malden        Bird  00BA  Inner London
# 75         Barnet      Mammal  00AC  Outer London
# 74        Lambeth      Mammal  00AY  Outer London
# 73       Dagenham      Mammal  00AB  Inner London
# 72     Park Royal        Bird  00AE  Outer London
# 71         Heston        Bird  00AT  Outer London
# 69         Purley        Bird  00AH  Outer London
# 68       Shadwell        Bird  00BG  Outer London
# 67        Hornsey      Mammal  00AP  Inner London

# %% [markdown]
# There are additional arguments we can set – by default the values are sorted in ascending order, by changing `ascending=False` we can sort in descending order.

# %%
animals_sorted = animals.sort_values(by="IncidentNominalCost(£)", ascending=False)
animals_sorted.head()
# Out:
#        IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 4450  098141-28072016  28/07/2016 13:49     2016  2016/17  Special Service
# 2542         48360131  19/04/2013 07:01     2013  2013/14  Special Service
# 3757         62700151  22/05/2015 11:34     2015  2015/16  Special Service
# 5568  092389-09072018  09/07/2018 08:35     2018  2018/19  Special Service
# 3143         49076141  22/04/2014 09:54     2014  2014/15  Special Service
#
#       PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 4450        3.0            12.0                   326                  3912.0
# 2542        2.0            12.0                   290                  3480.0
# 3757        2.0            10.0                   298                  2980.0
# 5568        2.0             8.0                   333                  2664.0
# 3143        2.0             9.0                   295                  2655.0
#
#                                        FinalDescription AnimalGroupParent  \
# 4450   CAT STUCK WITHIN WALL SPACE  RSPCA IN ATTENDANCE               Cat
# 2542          FOAL IN RIVER WATER LEVEL ONE IMPLEMENTED             Horse
# 3757                   HORSE FALLEN INTO SWIMMING  POOL             Horse
# 5568  HORSE TRAPPED IN DOORWAY ADDITIONAL FRU REQUES...             Horse
# 3143                          KITTEN TRAPPED IN CHIMNEY               Cat
#
#                                            PropertyType  \
# 4450  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 2542                                       River/canal
# 3757                          Other outdoor structures
# 5568                               Animal harm outdoors
# 3143  Purpose Built Flats/Maisonettes - Up to 3 stor...
#
#      SpecialServiceTypeCategory  \
# 4450    Other animal assistance
# 2542    Other animal assistance
# 3757   Animal rescue from water
# 5568    Other animal assistance
# 3143    Other animal assistance
#
#                                      SpecialServiceType         Borough  \
# 4450  Animal assistance involving domestic animal - ...          Camden
# 2542    Animal assistance - Lift heavy livestock animal  Waltham Forest
# 3757             Animal rescue from water - Farm animal         Bromley
# 5568     Animal assistance - Lift heavy domestic animal      Hillingdon
# 3143                     Assist trapped domestic animal        Hounslow
#
#      StnGroundName AnimalClass  Code        London
# 4450  Kentish Town      Mammal  00AG  Inner London
# 2542     Chingford      Mammal  00BH  Outer London
# 3757   Biggin Hill      Mammal  00AF  Outer London
# 5568    Hillingdon      Mammal  00AS  Outer London
# 3143       Feltham      Mammal  00AT  Outer London

# %% [markdown]
# We can also sort by more than one column by including a list.
#
# Here we are sorting by `"IncidentNominalCost(£)"`; and then by `"AnimalClass"`. Notice object (text/string) columns are sorted by *alphabetical* order.

# %%
animals_sorted = animals.sort_values(by=["IncidentNominalCost(£)", "AnimalClass"])
animals_sorted.head()
# Out:
#    IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 27        7051091  11/01/2009 12:32     2009  2008/09  Special Service
# 31        9252091  15/01/2009 12:38     2009  2008/09  Special Service
# 40       13245091  22/01/2009 21:35     2009  2008/09  Special Service
# 63       21760091  07/02/2009 11:12     2009  2008/09  Special Service
# 68       26715091  15/02/2009 15:53     2009  2008/09  Special Service
#
#     PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 27        1.0             1.0                   255                   255.0
# 31        1.0             1.0                   255                   255.0
# 40        1.0             1.0                   255                   255.0
# 63        1.0             1.0                   255                   255.0
# 68        1.0             1.0                   255                   255.0
#
#                                      FinalDescription AnimalGroupParent  \
# 27                             SWAN STUCK ON ROOF,B15              Bird
# 31  ASSIST RSPCA WITH BIRD TRAPPED IN TREE BY FOOT...              Bird
# 40                                BIRD IN CHIMNEY,B15              Bird
# 63                 PIGEON IN PRECARIOUS POSITION, B15              Bird
# 68                              SWAN IN DISTRESS, J15              Bird
#
#                                    PropertyType  \
# 27  Domestic garden (vegetation not equipment)
# 31                                   Wasteland
# 40                    House - single occupancy
# 63                                  Tree scrub
# 68                                 River/canal
#
#          SpecialServiceTypeCategory  \
# 27        Animal rescue from height
# 31        Animal rescue from height
# 40          Other animal assistance
# 63  Animal rescue from below ground
# 68         Animal rescue from water
#
#                                    SpecialServiceType        Borough  \
# 27                   Animal rescue from height - Bird       Havering
# 31                   Animal rescue from height - Bird        Lambeth
# 40  Animal assistance involving livestock - Other ...         Harrow
# 63             Animal rescue from below ground - Bird    Westminster
# 68                    Animal rescue from water - Bird  Tower Hamlets
#
#    StnGroundName AnimalClass  Code        London
# 27    Hornchurch        Bird  00AR  Outer London
# 31       Clapham        Bird  00AY  Inner London
# 40      Stanmore        Bird  00AQ  Outer London
# 63          Soho        Bird  00BK  Outer London
# 68      Shadwell        Bird  00BG  Outer London

# %% [markdown]
# When sorting more than one column in descending order it’s best to specify `ascending= ` as a list.
#
# This list is in the same order as our columns.
#
# Some versions of Pandas will sort both columns as descending if we just supply `ascending = False` ; however some won’t – so it’s better to be clear about what we want to do.
#
# By using a list I also have finer control – I could have one in ascending order, and one in descending order if I wished.

# %%
animals_sorted_desc = animals.sort_values(by=["IncidentNominalCost(£)", "AnimalGroupParent"], 
                                          ascending=[False, True])

animals_sorted_desc.head(30)
# Out:
#        IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 4450  098141-28072016  28/07/2016 13:49     2016  2016/17  Special Service
# 2542         48360131  19/04/2013 07:01     2013  2013/14  Special Service
# 3757         62700151  22/05/2015 11:34     2015  2015/16  Special Service
# 5568  092389-09072018  09/07/2018 08:35     2018  2018/19  Special Service
# 3143         49076141  22/04/2014 09:54     2014  2014/15  Special Service
# 1477        101755111  29/06/2011 21:04     2011  2011/12  Special Service
# 1289         49189111  06/04/2011 02:03     2011  2011/12  Special Service
# 1407         82423111  27/05/2011 06:50     2011  2011/12  Special Service
# 5328  030477-09032018  09/03/2018 14:30     2018  2017/18  Special Service
# 4797  028258-08032017  08/03/2017 10:15     2017  2016/17  Special Service
# 874         100611101  26/06/2010 15:29     2010  2010/11  Special Service
# 3605         11907151  29/01/2015 10:08     2015  2014/15  Special Service
# 2932        154461131  07/11/2013 15:46     2013  2013/14  Special Service
# 3060         22647141  23/02/2014 09:30     2014  2013/14  Special Service
# 185          78838091  11/05/2009 07:45     2009  2009/10  Special Service
# 492         191318091  20/10/2009 14:39     2009  2009/10  Special Service
# 4021        137141151  12/10/2015 16:07     2015  2015/16  Special Service
# 4090  171010-12122015  12/12/2015 12:47     2015  2015/16  Special Service
# 5591  098400-17072018  17/07/2018 16:16     2018  2018/19  Special Service
# 5703  125704-02092018  02/09/2018 17:16     2018  2018/19  Special Service
# 5709  126939-05092018  05/09/2018 13:41     2018  2018/19  Special Service
# 4860  046035-14042017  14/04/2017 13:23     2017  2017/18  Special Service
# 4814  033179-19032017  19/03/2017 15:18     2017  2016/17  Special Service
# 4597  139190-13102016  13/10/2016 09:58     2016  2016/17  Special Service
# 1138        207392101  09/12/2010 17:36     2010  2010/11  Special Service
# 449         170011091  18/09/2009 16:57     2009  2009/10  Special Service
# 3159         53105141  01/05/2014 08:00     2014  2014/15  Special Service
# 3559        170565141  22/12/2014 21:01     2014  2014/15  Special Service
# 2988           955141  03/01/2014 11:31     2014  2013/14  Special Service
# 5613  103432-24072018  24/07/2018 15:25     2018  2018/19  Special Service
#
#       PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 4450        3.0            12.0                   326                  3912.0
# 2542        2.0            12.0                   290                  3480.0
# 3757        2.0            10.0                   298                  2980.0
# 5568        2.0             8.0                   333                  2664.0
# 3143        2.0             9.0                   295                  2655.0
# 1477        3.0             9.0                   260                  2340.0
# 1289        3.0             9.0                   260                  2340.0
# 1407        3.0             9.0                   260                  2340.0
# 5328        2.0             7.0                   328                  2296.0
# 4797        2.0             7.0                   326                  2282.0
# 874         3.0             8.0                   260                  2080.0
# 3605        2.0             7.0                   295                  2065.0
# 2932        2.0             7.0                   290                  2030.0
# 3060        2.0             7.0                   290                  2030.0
# 185         3.0             7.0                   260                  1820.0
# 492         2.0             7.0                   260                  1820.0
# 4021        3.0             6.0                   298                  1788.0
# 4090        3.0             6.0                   298                  1788.0
# 5591        2.0             5.0                   333                  1665.0
# 5703        1.0             5.0                   333                  1665.0
# 5709        1.0             5.0                   333                  1665.0
# 4860        2.0             5.0                   328                  1640.0
# 4814        2.0             5.0                   326                  1630.0
# 4597        2.0             5.0                   326                  1630.0
# 1138        3.0             6.0                   260                  1560.0
# 449         2.0             6.0                   260                  1560.0
# 3159        2.0             5.0                   295                  1475.0
# 3559        2.0             5.0                   295                  1475.0
# 2988        1.0             5.0                   290                  1450.0
# 5613        2.0             4.0                   333                  1332.0
#
#                                        FinalDescription  \
# 4450   CAT STUCK WITHIN WALL SPACE  RSPCA IN ATTENDANCE
# 2542          FOAL IN RIVER WATER LEVEL ONE IMPLEMENTED
# 3757                   HORSE FALLEN INTO SWIMMING  POOL
# 5568  HORSE TRAPPED IN DOORWAY ADDITIONAL FRU REQUES...
# 3143                          KITTEN TRAPPED IN CHIMNEY
# 1477               DEER IN CANAL - WATER RESCUE LEVEL 2
# 1289  HORSE IN RIVER IMPLEMENT WATER RESCUE PROCEDUR...
# 1407  HORSE  TRAPPED IN WATER CHANNEL LINE OPS 2 WAT...
# 5328        LARGE ANIMAL RESCUE STAG TRAPPED IN FENCING
# 4797                   ASSIST RSPCA WITH CAT IN CHIMNEY
# 874                            CAT TRAPPED IN BIN CHUTE
# 3605                                 HORSE STUCK IN MUD
# 2932                      DOG TRAPPED BETWEEN TWO HOUSE
# 3060                             HORSE WEDGED IN STABLE
# 185   CAT TRAPPED ON RAFT ON CANAL WATER RESCUE LEVE...
# 492                      HORSE TRAPPED IN MUD AND WATER
# 4021   2 SWANS TRAPPEDIN LOCK GATES - LEVEL 2 WATER OPS
# 4090  HORSE TRAPPED IN DITCH LEVEL ONE HAZMAT FOUR P...
# 5591  PUPPY TRAPPED BETWEEN TWO HOUSES  FRU REQ FROM...
# 5703  HORSE STUCK IN DITCH AT REAR OF OCADO - OWNERS...
# 5709  ASSIST RSPCA WITH HORSE STUCK IN STREAM - WATE...
# 4860  CAT CAUGHT IN AXLE OF CAR FRU REQUESTED FROM S...
# 4814  DOG STUCK ON ISLAND IN LARGE POND WATER RESCUE...
# 4597  LARGE ANIMAL RESCUE - SEAL TRAPPED ON LAND WAT...
# 1138            COW STUCK IN MUD  WATER RESCUE LEVEL  2
# 449                               ROAD TRAFFIC ACCIDENT
# 3159                                SMALL ANIMAL RESCUE
# 3559  TO ASSIST RSPCA WITH KITTEN TRAPPED BETWEEN FI...
# 2988            ASSIST POLICE WITH HORSE INJURED IN RTC
# 5613  ASSIST RSPCA WITH BIRD TRAPPED IN NETTING IN P...
#
#                      AnimalGroupParent  \
# 4450                               Cat
# 2542                             Horse
# 3757                             Horse
# 5568                             Horse
# 3143                               Cat
# 1477                              Deer
# 1289                             Horse
# 1407                             Horse
# 5328             Unknown - Wild Animal
# 4797                               Cat
# 874                                Cat
# 3605                             Horse
# 2932                               Dog
# 3060                             Horse
# 185                                Cat
# 492                              Horse
# 4021                              Bird
# 4090                             Horse
# 5591                               Dog
# 5703                             Horse
# 5709                             Horse
# 4860                               Cat
# 4814                               Dog
# 4597             Unknown - Wild Animal
# 1138                               Cow
# 449   Unknown - Heavy Livestock Animal
# 3159                               Cat
# 3559                               Cat
# 2988                             Horse
# 5613                              Bird
#
#                                            PropertyType  \
# 4450  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 2542                                       River/canal
# 3757                          Other outdoor structures
# 5568                               Animal harm outdoors
# 3143  Purpose Built Flats/Maisonettes - Up to 3 stor...
# 1477                                       River/canal
# 1289                                       River/canal
# 1407                                       River/canal
# 5328              Woodland/forest - broadleaf/hardwood
# 4797     Converted Flat/Maisonettes - 3 or more storeys
# 874   Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 3605                   Grassland, pasture, grazing etc
# 2932                          House - single occupancy
# 3060       Other animal boarding/breeding establishment
# 185                                        River/canal
# 492                                        River/canal
# 4021                                       River/canal
# 4090                   Grassland, pasture, grazing etc
# 5591                          House - single occupancy
# 5703                                         Wasteland
# 5709                               Lake/pond/reservoir
# 4860                                               Car
# 4814                               Lake/pond/reservoir
# 4597                               Animal harm outdoors
# 1138                                       River/canal
# 449                              Road surface/pavement
# 3159                        Canal/riverbank vegetation
# 3559                                       Single shop
# 2988                               Animal harm outdoors
# 5613                               Lake/pond/reservoir
#
#            SpecialServiceTypeCategory  \
# 4450          Other animal assistance
# 2542          Other animal assistance
# 3757         Animal rescue from water
# 5568          Other animal assistance
# 3143          Other animal assistance
# 1477         Animal rescue from water
# 1289         Animal rescue from water
# 1407         Animal rescue from water
# 5328          Other animal assistance
# 4797        Animal rescue from height
# 874         Animal rescue from height
# 3605         Animal rescue from water
# 2932          Other animal assistance
# 3060          Other animal assistance
# 185          Animal rescue from water
# 492          Animal rescue from water
# 4021         Animal rescue from water
# 4090          Other animal assistance
# 5591          Other animal assistance
# 5703  Animal rescue from below ground
# 5709         Animal rescue from water
# 4860          Other animal assistance
# 4814         Animal rescue from water
# 4597          Other animal assistance
# 1138         Animal rescue from water
# 449           Other animal assistance
# 3159         Animal rescue from water
# 3559          Other animal assistance
# 2988          Other animal assistance
# 5613         Animal rescue from water
#
#                                      SpecialServiceType               Borough  \
# 4450  Animal assistance involving domestic animal - ...                Camden
# 2542    Animal assistance - Lift heavy livestock animal        Waltham Forest
# 3757             Animal rescue from water - Farm animal               Bromley
# 5568     Animal assistance - Lift heavy domestic animal            Hillingdon
# 3143                     Assist trapped domestic animal              Hounslow
# 1477               Wild animal rescue from water or mud         Tower Hamlets
# 1289             Animal rescue from water - Farm animal        Waltham Forest
# 1407             Animal rescue from water - Farm animal        Waltham Forest
# 5328                         Assist trapped wild animal               Bromley
# 4797           Animal rescue from height - Domestic pet             Islington
# 874            Animal rescue from height - Domestic pet           Westminster
# 3605             Animal rescue from water - Farm animal                Bexley
# 2932                     Assist trapped domestic animal                Bexley
# 3060  Animal assistance involving domestic animal - ...               Bromley
# 185             Animal rescue from water - Domestic pet         Tower Hamlets
# 492              Animal rescue from water - Farm animal            Hillingdon
# 4021                    Animal rescue from water - Bird              Haringey
# 4090                     Assist trapped domestic animal            Hillingdon
# 5591                     Assist trapped domestic animal               Enfield
# 5703      Animal rescue from below ground - Farm animal                Bexley
# 5709             Animal rescue from water - Farm animal                Bexley
# 4860                     Assist trapped domestic animal            Wandsworth
# 4814            Animal rescue from water - Domestic pet            Wandsworth
# 4597         Animal assistance - Lift heavy wild animal              Hounslow
# 1138             Animal rescue from water - Farm animal              Havering
# 449     Animal assistance - Lift heavy livestock animal                Bexley
# 3159            Animal rescue from water - Domestic pet         Tower Hamlets
# 3559                     Assist trapped domestic animal  Kingston Upon Thames
# 2988    Animal assistance - Lift heavy livestock animal        Waltham Forest
# 5613                    Animal rescue from water - Bird               Bromley
#
#          StnGroundName AnimalClass  Code        London
# 4450      Kentish Town      Mammal  00AG  Inner London
# 2542         Chingford      Mammal  00BH  Outer London
# 3757       Biggin Hill      Mammal  00AF  Outer London
# 5568        Hillingdon      Mammal  00AS  Outer London
# 3143           Feltham      Mammal  00AT  Outer London
# 1477            Poplar      Mammal  00BG  Inner London
# 1289       Walthamstow      Mammal  00BH  Outer London
# 1407       Walthamstow      Mammal  00BH  Outer London
# 5328       Biggin Hill      Mammal  00AF  Inner London
# 4797          Holloway      Mammal  00AU  Outer London
# 874   North Kensington      Mammal  00BK  Inner London
# 3605             Erith      Mammal  00AD  Inner London
# 2932            Sidcup      Mammal  00AD  Outer London
# 3060            Eltham      Mammal  00AF  Outer London
# 185             Poplar      Mammal  00BG  Inner London
# 492              Hayes      Mammal  00AS  Outer London
# 4021         Tottenham        Bird  00AP  Outer London
# 4090           Ruislip      Mammal  00AS  Outer London
# 5591          Edmonton      Mammal  00AK  Inner London
# 5703             Erith      Mammal  00AD  Inner London
# 5709             Erith      Mammal  00AD  Outer London
# 4860        Wandsworth      Mammal  00BJ  Inner London
# 4814           Tooting      Mammal  00BJ  Outer London
# 4597          Chiswick      Mammal  00AT  Outer London
# 1138        Hornchurch      Mammal  00AR  Outer London
# 449             Sidcup      Mammal  00AD  Outer London
# 3159            Poplar      Mammal  00BG  Outer London
# 3559          Kingston      Mammal  00AX  Inner London
# 2988         Chingford      Mammal  00BH  Outer London
# 5613            Sidcup        Bird  00AF  Outer London

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise 1
#
# Sort the `titanic` DataFrame by the `age` column in descending order.

# %%
# Exercise

titanic_sorted = titanic.sort_values(by = "age", ascending= False)
titanic_sorted
# Out:
#       pclass  survived                                               name  \
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 1235       3         0                                Svensson, Mr. Johan
# 135        1         0                          Goldschmidt, Mr. George B
# 9          1         0                            Artagaveytia, Mr. Ramon
# 727        3         0                               Connors, Mr. Patrick
# 81         1         0                       Crosby, Capt. Edward Gifford
# 506        2         0                        Mitchell, Mr. Henry Michael
# 285        1         0                                 Straus, Mr. Isidor
# 594        2         0                              Wheadon, Mr. Edward H
# 782        3         0                                   Duane, Mr. Frank
# 221        1         0                     Ostby, Mr. Engelhart Cornelius
# 205        1         0                          Millet, Mr. Francis Davis
# 217        1         0                       Nicholson, Mr. Arthur Ernest
# 83         1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 78         1         1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 115        1         0                                  Fortune, Mr. Mark
# 303        1         0                           Warren, Mr. Frank Manley
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 286        1         0             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 1261       3         1                             Turkula, Mrs. (Hedwig)
# 455        2         0                               Howard, Mr. Benjamin
# 432        2         1                                 Harris, Mr. George
# 321        1         0                                 Wright, Mr. George
# 511        2         0                          Myles, Mr. Thomas Francis
# 279        1         0                          Stead, Mr. William Thomas
# 284        1         1          Stone, Mrs. George Nelson (Martha Evelyn)
# 1068       3         0                          Nysveen, Mr. Johan Hansen
# 252        1         0                         Ryerson, Mr. Arthur Larned
# 287        1         0                              Sutton, Mr. Frederick
# ...      ...       ...                                                ...
# 1202       3         0                                Sirota, Mr. Maurice
# 1212       3         0                               Slabenoff, Mr. Petco
# 1213       3         0                      Slocovski, Mr. Selman Francis
# 1214       3         0                                Smiljanic, Mr. Mile
# 1215       3         0                                  Smith, Mr. Thomas
# 1216       3         1                                 Smyth, Miss. Julia
# 1219       3         0                                 Spector, Mr. Woolf
# 1221       3         0                                  Staneff, Mr. Ivan
# 1241       3         0                              Thomas, Mr. Charles P
# 1242       3         0                                   Thomas, Mr. John
# 1243       3         0                                Thomas, Mr. Tannous
# 1245       3         0                    Thomson, Mr. Alexander Morrison
# 1246       3         0                         Thorneycroft, Mr. Percival
# 1247       3         1  Thorneycroft, Mrs. Percival (Florence Kate White)
# 1249       3         0                                   Tobin, Mr. Roger
# 1250       3         0                                Todoroff, Mr. Lalio
# 1253       3         0                                   Torfa, Mr. Assad
# 1255       3         0                                  Toufik, Mr. Nakli
# 1262       3         0                van Billiard, Master. James William
# 1268       3         0                        van Melkebeke, Mr. Philemon
# 1282       3         0                                Ware, Mr. Frederick
# 1283       3         0                        Warren, Mr. Charles William
# 1284       3         0                                  Webber, Mr. James
# 1291       3         0                   Willer, Mr. Aaron ("Abi Weller")
# 1292       3         0                                 Willey, Mr. Edward
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch            ticket      fare            cabin  \
# 14      male  80.0      0      0             27042   30.0000              A23
# 61    female  76.0      1      0             19877   78.8500              C46
# 1235    male  74.0      0      0            347060    7.7750              NaN
# 135     male  71.0      0      0          PC 17754   34.6542               A5
# 9       male  71.0      0      0          PC 17609   49.5042              NaN
# 727     male  70.5      0      0            370369    7.7500              NaN
# 81      male  70.0      1      1         WE/P 5735   71.0000              B22
# 506     male  70.0      0      0        C.A. 24580   10.5000              NaN
# 285     male  67.0      1      0          PC 17483  221.7792          C55 C57
# 594     male  66.0      0      0        C.A. 24579   10.5000              NaN
# 782     male  65.0      0      0            336439    7.7500              NaN
# 221     male  65.0      0      1            113509   61.9792              B30
# 205     male  65.0      0      0             13509   26.5500              E38
# 217     male  64.0      0      0               693   26.0000              NaN
# 83    female  64.0      1      1            112901   26.5500              B26
# 78    female  64.0      0      2          PC 17756   83.1583              E45
# 115     male  64.0      1      4             19950  263.0000      C23 C25 C27
# 303     male  64.0      1      0            110813   75.2500              D37
# 6     female  63.0      1      0             13502   77.9583               D7
# 286   female  63.0      1      0          PC 17483  221.7792          C55 C57
# 1261  female  63.0      0      0              4134    9.5875              NaN
# 455     male  63.0      1      0             24065   26.0000              NaN
# 432     male  62.0      0      0       S.W./PP 752   10.5000              NaN
# 321     male  62.0      0      0            113807   26.5500              NaN
# 511     male  62.0      0      0            240276    9.6875              NaN
# 279     male  62.0      0      0            113514   26.5500              C87
# 284   female  62.0      0      0            113572   80.0000              B28
# 1068    male  61.0      0      0            345364    6.2375              NaN
# 252     male  61.0      1      3          PC 17608  262.3750  B57 B59 B63 B66
# 287     male  61.0      0      0             36963   32.3208              D50
# ...      ...   ...    ...    ...               ...       ...              ...
# 1202    male   NaN      0      0            392092    8.0500              NaN
# 1212    male   NaN      0      0            349214    7.8958              NaN
# 1213    male   NaN      0      0   SOTON/OQ 392086    8.0500              NaN
# 1214    male   NaN      0      0            315037    8.6625              NaN
# 1215    male   NaN      0      0            384461    7.7500              NaN
# 1216  female   NaN      0      0            335432    7.7333              NaN
# 1219    male   NaN      0      0         A.5. 3236    8.0500              NaN
# 1221    male   NaN      0      0            349208    7.8958              NaN
# 1241    male   NaN      1      0              2621    6.4375              NaN
# 1242    male   NaN      0      0              2681    6.4375              NaN
# 1243    male   NaN      0      0              2684    7.2250              NaN
# 1245    male   NaN      0      0             32302    8.0500              NaN
# 1246    male   NaN      1      0            376564   16.1000              NaN
# 1247  female   NaN      1      0            376564   16.1000              NaN
# 1249    male   NaN      0      0            383121    7.7500              F38
# 1250    male   NaN      0      0            349216    7.8958              NaN
# 1253    male   NaN      0      0              2673    7.2292              NaN
# 1255    male   NaN      0      0              2641    7.2292              NaN
# 1262    male   NaN      1      1          A/5. 851   14.5000              NaN
# 1268    male   NaN      0      0            345777    9.5000              NaN
# 1282    male   NaN      0      0            359309    8.0500              NaN
# 1283    male   NaN      0      0        C.A. 49867    7.5500              NaN
# 1284    male   NaN      0      0  SOTON/OQ 3101316    8.0500              NaN
# 1291    male   NaN      0      0              3410    8.7125              NaN
# 1292    male   NaN      0      0     S.O./P.P. 751    7.5500              NaN
# 1293    male   NaN      0      0          A/5 2466    8.0500              NaN
# 1297    male   NaN      0      0        A/4. 34244    7.2500              NaN
# 1302    male   NaN      0      0              2647    7.2250              NaN
# 1303    male   NaN      0      0              2627   14.4583              NaN
# 1305  female   NaN      1      0              2665   14.4542              NaN
#
#      embarked                                       home.dest   body boat  \
# 14          S                                   Hessle, Yorks    NaN    B
# 61          S                         Little Onn Hall, Staffs    NaN    6
# 1235        S                                             NaN    NaN  NaN
# 135         C                                    New York, NY    NaN  NaN
# 9           C                             Montevideo, Uruguay   22.0  NaN
# 727         Q                                             NaN  171.0  NaN
# 81          S                                   Milwaukee, WI  269.0  NaN
# 506         S    Guernsey / Montclair, NJ and/or Toledo, Ohio    NaN  NaN
# 285         S                                    New York, NY   96.0  NaN
# 594         S                Guernsey, England / Edgewood, RI    NaN  NaN
# 782         Q                                             NaN    NaN  NaN
# 221         C                                  Providence, RI  234.0  NaN
# 205         S                            East Bridgewater, MA  249.0  NaN
# 217         S                          Isle of Wight, England  263.0  NaN
# 83          S                                   Milwaukee, WI    NaN    7
# 78          C                                    Lakewood, NJ    NaN   14
# 115         S                                    Winnipeg, MB    NaN  NaN
# 303         C                                    Portland, OR    NaN  NaN
# 6           S                                      Hudson, NY    NaN   10
# 286         S                                    New York, NY    NaN  NaN
# 1261        S                                             NaN    NaN   15
# 455         S                                Swindon, England    NaN  NaN
# 432         S                                          London    NaN   15
# 321         S                                     Halifax, NS    NaN  NaN
# 511         Q                                   Cambridge, MA    NaN  NaN
# 279         S  Wimbledon Park, London / Hayling Island, Hants    NaN  NaN
# 284       NaN                                  Cincinatti, OH    NaN    6
# 1068        S                                             NaN    NaN  NaN
# 252         C                 Haverford, PA / Cooperstown, NY    NaN  NaN
# 287         S                                 Haddenfield, NJ   46.0  NaN
# ...       ...                                             ...    ...  ...
# 1202        S                                             NaN    NaN  NaN
# 1212        S                                             NaN    NaN  NaN
# 1213        S                                             NaN    NaN  NaN
# 1214        S                                             NaN    NaN  NaN
# 1215        Q                                             NaN    NaN  NaN
# 1216        Q                                             NaN    NaN   13
# 1219        S                                             NaN    NaN  NaN
# 1221        S                                             NaN    NaN  NaN
# 1241        C                                             NaN    NaN  NaN
# 1242        C                                             NaN    NaN  NaN
# 1243        C                                             NaN    NaN  NaN
# 1245        S                                             NaN    NaN  NaN
# 1246        S                                             NaN    NaN  NaN
# 1247        S                                             NaN    NaN   10
# 1249        Q                                             NaN    NaN  NaN
# 1250        S                                             NaN    NaN  NaN
# 1253        C                                             NaN    NaN  NaN
# 1255        C                                             NaN    NaN  NaN
# 1262        S                                             NaN    NaN  NaN
# 1268        S                                             NaN    NaN  NaN
# 1282        S                                             NaN    NaN  NaN
# 1283        S                                             NaN    NaN  NaN
# 1284        S                                             NaN    NaN  NaN
# 1291        S                                             NaN    NaN  NaN
# 1292        S                                             NaN    NaN  NaN
# 1293        S                                             NaN    NaN  NaN
# 1297        S                                             NaN    NaN  NaN
# 1302        C                                             NaN    NaN  NaN
# 1303        C                                             NaN    NaN  NaN
# 1305        C                                             NaN    NaN  NaN
#
#       bool_surv
# 14         True
# 61         True
# 1235      False
# 135       False
# 9         False
# 727       False
# 81        False
# 506       False
# 285       False
# 594       False
# 782       False
# 221       False
# 205       False
# 217       False
# 83         True
# 78         True
# 115       False
# 303       False
# 6          True
# 286       False
# 1261       True
# 455       False
# 432        True
# 321       False
# 511       False
# 279       False
# 284        True
# 1068      False
# 252       False
# 287       False
# ...         ...
# 1202      False
# 1212      False
# 1213      False
# 1214      False
# 1215      False
# 1216       True
# 1219      False
# 1221      False
# 1241      False
# 1242      False
# 1243      False
# 1245      False
# 1246      False
# 1247       True
# 1249      False
# 1250      False
# 1253      False
# 1255      False
# 1262      False
# 1268      False
# 1282      False
# 1283      False
# 1284      False
# 1291      False
# 1292      False
# 1293      False
# 1297      False
# 1302      False
# 1303      False
# 1305      False
#
# [1309 rows x 15 columns]

# %%
# %load ../solutions/chapter_4/titanic_sort_one.py
# Sort the titanic DataFrame by the age column

titanic_sorted = titanic.sort_values(by="age", ascending=False)
titanic_sorted.head(20)

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise 2
#
# Sort the `titanic` DataFrame by the `age` and `sex` column

# %%
# Exercise

# %%
# %load ../solutions/chapter_4/titanic_sort_two.py
# Sort the titanic DataFrame by the age column

titanic_sorted = titanic.sort_values(by=["age", "sex"])
titanic_sorted.head(20)

# Check out indexes 657, 658 and 1111. 
# They are sorted first by age (0.75) and then by sex 
# with Female being first, as F is before M alphabetically.
# Out:
#       pclass  survived                                     name     sex  \
# 763        3         1  Dean, Miss. Elizabeth Gladys "Millvina"  female
# 747        3         0  Danbom, Master. Gilbert Sigvard Emanuel    male
# 1240       3         1          Thomas, Master. Assad Alexander    male
# 427        2         1                Hamalainen, Master. Viljo    male
# 657        3         1                   Baclini, Miss. Eugenie  female
# 658        3         1            Baclini, Miss. Helene Barbara  female
# 1111       3         0           Peacock, Master. Alfred Edward    male
# 359        2         1            Caldwell, Master. Alden Gates    male
# 548        2         1          Richards, Master. George Sibley    male
# 611        3         1                Aks, Master. Philip Frank    male
# 590        2         1                    West, Miss. Barbara J  female
# 1          1         1           Allison, Master. Hudson Trevor    male
# 478        2         1                    Laroche, Miss. Louise  female
# 895        3         1             Johnson, Miss. Eleanor Ileen  female
# 937        3         0             Klasen, Miss. Gertrud Emilia  female
# 1048       3         1              Nakid, Miss. Maria ("Mary")  female
# 1187       3         1          Sandstrom, Miss. Beatrice Irene  female
# 339        2         1                Becker, Master. Richard F    male
# 492        2         1                    Mallet, Master. Andre    male
# 762        3         1               Dean, Master. Bertram Vere    male
#
#          age  sibsp  parch              ticket      fare    cabin embarked  \
# 763   0.1667      1      2           C.A. 2315   20.5750      NaN        S
# 747   0.3333      0      2              347080   14.4000      NaN        S
# 1240  0.4167      0      1                2625    8.5167      NaN        C
# 427   0.6667      1      1              250649   14.5000      NaN        S
# 657   0.7500      2      1                2666   19.2583      NaN        C
# 658   0.7500      2      1                2666   19.2583      NaN        C
# 1111  0.7500      1      1  SOTON/O.Q. 3101315   13.7750      NaN        S
# 359   0.8333      0      2              248738   29.0000      NaN        S
# 548   0.8333      1      1               29106   18.7500      NaN        S
# 611   0.8333      0      1              392091    9.3500      NaN        S
# 590   0.9167      1      2          C.A. 34651   27.7500      NaN        S
# 1     0.9167      1      2              113781  151.5500  C22 C26        S
# 478   1.0000      1      2       SC/Paris 2123   41.5792      NaN        C
# 895   1.0000      1      1              347742   11.1333      NaN        S
# 937   1.0000      1      1              350405   12.1833      NaN        S
# 1048  1.0000      0      2                2653   15.7417      NaN        C
# 1187  1.0000      1      1             PP 9549   16.7000       G6        S
# 339   1.0000      2      1              230136   39.0000       F4        S
# 492   1.0000      0      2     S.C./PARIS 2079   37.0042      NaN        C
# 762   1.0000      1      2           C.A. 2315   20.5750      NaN        S
#
#                                home.dest  body boat  bool_surv
# 763           Devon, England Wichita, KS   NaN   10       True
# 747                          Stanton, IA   NaN  NaN      False
# 1240                                 NaN   NaN   16       True
# 427                          Detroit, MI   NaN    4       True
# 657                   Syria New York, NY   NaN    C       True
# 658                   Syria New York, NY   NaN    C       True
# 1111                                 NaN   NaN  NaN      False
# 359    Bangkok, Thailand / Roseville, IL   NaN   13       True
# 548                 Cornwall / Akron, OH   NaN    4       True
# 611          London, England Norfolk, VA   NaN   11       True
# 590                  Bournmouth, England   NaN   10       True
# 1        Montreal, PQ / Chesterville, ON   NaN   11       True
# 478                        Paris / Haiti   NaN   14       True
# 895                                  NaN   NaN   15       True
# 937                                  NaN   NaN  NaN      False
# 1048                                 NaN   NaN    C       True
# 1187                                 NaN   NaN   13       True
# 339   Guntur, India / Benton Harbour, MI   NaN   11       True
# 492                 Paris / Montreal, PQ   NaN   10       True
# 762           Devon, England Wichita, KS   NaN   10       True

# %% [markdown]
# <hr style="width:70%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %%
animals_sorted = animals.sort_values(by = "IncidentNominalCost(£)", ascending= False)
animals_sorted.head()
# Out:
#        IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 4450  098141-28072016  28/07/2016 13:49     2016  2016/17  Special Service
# 2542         48360131  19/04/2013 07:01     2013  2013/14  Special Service
# 3757         62700151  22/05/2015 11:34     2015  2015/16  Special Service
# 5568  092389-09072018  09/07/2018 08:35     2018  2018/19  Special Service
# 3143         49076141  22/04/2014 09:54     2014  2014/15  Special Service
#
#       PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 4450        3.0            12.0                   326                  3912.0
# 2542        2.0            12.0                   290                  3480.0
# 3757        2.0            10.0                   298                  2980.0
# 5568        2.0             8.0                   333                  2664.0
# 3143        2.0             9.0                   295                  2655.0
#
#                                        FinalDescription AnimalGroupParent  \
# 4450   CAT STUCK WITHIN WALL SPACE  RSPCA IN ATTENDANCE               Cat
# 2542          FOAL IN RIVER WATER LEVEL ONE IMPLEMENTED             Horse
# 3757                   HORSE FALLEN INTO SWIMMING  POOL             Horse
# 5568  HORSE TRAPPED IN DOORWAY ADDITIONAL FRU REQUES...             Horse
# 3143                          KITTEN TRAPPED IN CHIMNEY               Cat
#
#                                            PropertyType  \
# 4450  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 2542                                       River/canal
# 3757                          Other outdoor structures
# 5568                               Animal harm outdoors
# 3143  Purpose Built Flats/Maisonettes - Up to 3 stor...
#
#      SpecialServiceTypeCategory  \
# 4450    Other animal assistance
# 2542    Other animal assistance
# 3757   Animal rescue from water
# 5568    Other animal assistance
# 3143    Other animal assistance
#
#                                      SpecialServiceType         Borough  \
# 4450  Animal assistance involving domestic animal - ...          Camden
# 2542    Animal assistance - Lift heavy livestock animal  Waltham Forest
# 3757             Animal rescue from water - Farm animal         Bromley
# 5568     Animal assistance - Lift heavy domestic animal      Hillingdon
# 3143                     Assist trapped domestic animal        Hounslow
#
#      StnGroundName AnimalClass  Code        London
# 4450  Kentish Town      Mammal  00AG  Inner London
# 2542     Chingford      Mammal  00BH  Outer London
# 3757   Biggin Hill      Mammal  00AF  Outer London
# 5568    Hillingdon      Mammal  00AS  Outer London
# 3143       Feltham      Mammal  00AT  Outer London

# %% [markdown]
# ## Revisiting parameters and arguments
#
# We'll reinforce parameters and an arguments now.
#
# Parameters are key words that tell python what the following argument relates to. We have two in the code below:
#
# `by= ` is a parameter and the string representing the column `"IncidentNominalCost(£)"` is the argument.
#
# `ascending= ` is a parameter and `False` is the argument
#
# If we don’t specify parameters Python will assume our arguments are in the order specified in the Signature (press `shift + tab` with your cursor in `.sort_values()` to see this)
#
# Because of this the code below won’t work.

# %%
# This code may give us an error!
# If it doesn't give you an error your data may still be in ascending order

# After you've tried it, you may want to comment it out!

animals_sorted = animals.sort_values("IncidentNominalCost(£)", 0, False)

animals_sorted.head()
# Out:
#        IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 4450  098141-28072016  28/07/2016 13:49     2016  2016/17  Special Service
# 2542         48360131  19/04/2013 07:01     2013  2013/14  Special Service
# 3757         62700151  22/05/2015 11:34     2015  2015/16  Special Service
# 5568  092389-09072018  09/07/2018 08:35     2018  2018/19  Special Service
# 3143         49076141  22/04/2014 09:54     2014  2014/15  Special Service
#
#       PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 4450        3.0            12.0                   326                  3912.0
# 2542        2.0            12.0                   290                  3480.0
# 3757        2.0            10.0                   298                  2980.0
# 5568        2.0             8.0                   333                  2664.0
# 3143        2.0             9.0                   295                  2655.0
#
#                                        FinalDescription AnimalGroupParent  \
# 4450   CAT STUCK WITHIN WALL SPACE  RSPCA IN ATTENDANCE               Cat
# 2542          FOAL IN RIVER WATER LEVEL ONE IMPLEMENTED             Horse
# 3757                   HORSE FALLEN INTO SWIMMING  POOL             Horse
# 5568  HORSE TRAPPED IN DOORWAY ADDITIONAL FRU REQUES...             Horse
# 3143                          KITTEN TRAPPED IN CHIMNEY               Cat
#
#                                            PropertyType  \
# 4450  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 2542                                       River/canal
# 3757                          Other outdoor structures
# 5568                               Animal harm outdoors
# 3143  Purpose Built Flats/Maisonettes - Up to 3 stor...
#
#      SpecialServiceTypeCategory  \
# 4450    Other animal assistance
# 2542    Other animal assistance
# 3757   Animal rescue from water
# 5568    Other animal assistance
# 3143    Other animal assistance
#
#                                      SpecialServiceType         Borough  \
# 4450  Animal assistance involving domestic animal - ...          Camden
# 2542    Animal assistance - Lift heavy livestock animal  Waltham Forest
# 3757             Animal rescue from water - Farm animal         Bromley
# 5568     Animal assistance - Lift heavy domestic animal      Hillingdon
# 3143                     Assist trapped domestic animal        Hounslow
#
#      StnGroundName AnimalClass  Code        London
# 4450  Kentish Town      Mammal  00AG  Inner London
# 2542     Chingford      Mammal  00BH  Outer London
# 3757   Biggin Hill      Mammal  00AF  Outer London
# 5568    Hillingdon      Mammal  00AS  Outer London
# 3143       Feltham      Mammal  00AT  Outer London

# %% [markdown]
# Our first argument `IncidentNominalCost(£)` maps directly to the `by=` parameter.
#
# However, Python assumes the second argument `False` relates to the `axis = ` parameter; which in some versions isn't a valid argument, and in some pandas versions is treated effectively as `axis =0`.
#
# It is personal preference if you use parameters before your arguments. It is considered good practice, and can make your code more readable, especially to new coders. We would strongly advise doing so.

# %%
help(animals.sort_values)
# Out:
# Help on method sort_values in module pandas.core.frame:
#
# sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last') method of pandas.core.frame.DataFrame instance
#     Sort by the values along either axis
#
#     .. versionadded:: 0.17.0
#
#     Parameters
#     ----------
#     by : str or list of str
#         Name or list of names which refer to the axis items.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Axis to direct sorting
#     ascending : bool or list of bool, default True
#          Sort ascending vs. descending. Specify list for multiple sort
#          orders.  If this is a list of bools, must match the length of
#          the by.
#     inplace : bool, default False
#          if True, perform operation in-place
#     kind : {'quicksort', 'mergesort', 'heapsort'}, default 'quicksort'
#          Choice of sorting algorithm. See also ndarray.np.sort for more
#          information.  `mergesort` is the only stable algorithm. For
#          DataFrames, this option is only applied when sorting on a single
#          column or label.
#     na_position : {'first', 'last'}, default 'last'
#          `first` puts NaNs at the beginning, `last` puts NaNs at the end
#
#     Returns
#     -------
#     sorted_obj : DataFrame

# %%
animals_sorted = animals.sort_values(ascending=False, by="IncidentNominalCost(£)")
animals_sorted.head()
# Out:
#        IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 4450  098141-28072016  28/07/2016 13:49     2016  2016/17  Special Service
# 2542         48360131  19/04/2013 07:01     2013  2013/14  Special Service
# 3757         62700151  22/05/2015 11:34     2015  2015/16  Special Service
# 5568  092389-09072018  09/07/2018 08:35     2018  2018/19  Special Service
# 3143         49076141  22/04/2014 09:54     2014  2014/15  Special Service
#
#       PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 4450        3.0            12.0                   326                  3912.0
# 2542        2.0            12.0                   290                  3480.0
# 3757        2.0            10.0                   298                  2980.0
# 5568        2.0             8.0                   333                  2664.0
# 3143        2.0             9.0                   295                  2655.0
#
#                                        FinalDescription AnimalGroupParent  \
# 4450   CAT STUCK WITHIN WALL SPACE  RSPCA IN ATTENDANCE               Cat
# 2542          FOAL IN RIVER WATER LEVEL ONE IMPLEMENTED             Horse
# 3757                   HORSE FALLEN INTO SWIMMING  POOL             Horse
# 5568  HORSE TRAPPED IN DOORWAY ADDITIONAL FRU REQUES...             Horse
# 3143                          KITTEN TRAPPED IN CHIMNEY               Cat
#
#                                            PropertyType  \
# 4450  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 2542                                       River/canal
# 3757                          Other outdoor structures
# 5568                               Animal harm outdoors
# 3143  Purpose Built Flats/Maisonettes - Up to 3 stor...
#
#      SpecialServiceTypeCategory  \
# 4450    Other animal assistance
# 2542    Other animal assistance
# 3757   Animal rescue from water
# 5568    Other animal assistance
# 3143    Other animal assistance
#
#                                      SpecialServiceType         Borough  \
# 4450  Animal assistance involving domestic animal - ...          Camden
# 2542    Animal assistance - Lift heavy livestock animal  Waltham Forest
# 3757             Animal rescue from water - Farm animal         Bromley
# 5568     Animal assistance - Lift heavy domestic animal      Hillingdon
# 3143                     Assist trapped domestic animal        Hounslow
#
#      StnGroundName AnimalClass  Code        London
# 4450  Kentish Town      Mammal  00AG  Inner London
# 2542     Chingford      Mammal  00BH  Outer London
# 3757   Biggin Hill      Mammal  00AF  Outer London
# 5568    Hillingdon      Mammal  00AS  Outer London
# 3143       Feltham      Mammal  00AT  Outer London

# %% [markdown]
# As a bonus when you use parameters with your arguments you can pass them in any order as Python no longer relies on it being a positional based argument.
#
# So this code with the argument reversed will also work.

# %% [markdown]
# [return to menu](#menu)

# %% [markdown]
# <a id='subsetting'></a>
# <hr style="width:100%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:1">

# %% [markdown]
# ## Subsetting

# %% [markdown]
# ### Selecting Single Columns

# %% [markdown]
# Sometimes we will want to work with smaller “cut down” DataFrames that contain fewer columns.
#
# As we saw earlier the simplest way to select a column from a DataFrame is to use the name of the column.
#
# Here I am creating a new Series called ‘animal_grp_parent’ using the ‘AnimalGroupParent’ column from the animals DataFrame.

# %%
animal_grp_parent = animals['AnimalGroupParent']

animal_grp_parent.sample(6)
# Out:
# 2932     Dog
# 5285     Cat
# 2210    Bird
# 1235     Cat
# 239      Cat
# 3522     Dog
# Name: AnimalGroupParent, dtype: object

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise
#
# Select the `fare` column from the `titanic` DataFrame.

# %%
# Exercise

titanic["fare"].head()
# Out:
# 0    211.3375
# 1    151.5500
# 2    151.5500
# 3    151.5500
# 4    151.5500
# Name: fare, dtype: float64

# %%
# %load ../solutions/chapter_4/titanic_select.py
# Select the fare column from the titanic DataFrame.

titanic_fare = titanic["fare"]
titanic_fare.head()

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Selecting Multiple Columns

# %% [markdown]
# I can select multiple columns by providing them in a list within my indexing (or selection) square brackets.
#
# Here we have two sets of square brackets next to each other. It’s important to realise that they are doing two separate roles. Our first set is selecting or indexing from the animals DataFrame and our second set is creating a list of our columns we wish to select.

# %%
columns_list = [ "DateTimeOfCall", "AnimalGroupParent", "IncidentNominalCost(£)"]

animals_small_df_1 = animals[columns_list]
animals_small_df_1.sample(6)
# Out:
#         DateTimeOfCall      AnimalGroupParent  IncidentNominalCost(£)
# 2335  13/11/2012 09:06                    Dog                   260.0
# 745   24/04/2010 13:38                    Cat                   260.0
# 605   18/01/2010 09:59                    Cat                   260.0
# 5125  07/09/2017 12:14                    Cat                   328.0
# 2066  07/06/2012 16:02  Unknown - Wild Animal                   260.0
# 5158  30/09/2017 16:39                    Cat                   328.0

# %%
animal_small_df = animals[  [ "DateTimeOfCall", "AnimalGroupParent", "IncidentNominalCost(£)"]   ]
animal_small_df.sample(6)
# Out:
#         DateTimeOfCall AnimalGroupParent  IncidentNominalCost(£)
# 1077  17/10/2010 16:24              Bird                   260.0
# 1609  26/08/2011 20:21               Dog                   260.0
# 3790  10/06/2015 01:37               Cat                   298.0
# 2874  25/09/2013 09:50               Cat                   580.0
# 3967  31/08/2015 20:28               Cat                   298.0
# 29    12/01/2009 16:39               Dog                   255.0

# %% [markdown]
# Note that when we return one column we get a Series object.
#
# When we return more than one column we get a DataFrame.

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise
#
# Select the `name, sex, age` and `survived` column from the `titanic` DataFrame.

# %%
# Exercise

titanic_columns = ["name", "sex", "age", "survived"]

small_titanic = titanic[titanic_columns]

small_titanic.head()
# Out:
#                                               name     sex      age  survived
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000         1
# 1                   Allison, Master. Hudson Trevor    male   0.9167         1
# 2                     Allison, Miss. Helen Loraine  female   2.0000         0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000         0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000         0

# %%
# %load ../solutions/chapter_4/titanic_select_two.py
# Select the name,sex,age and survived column from the titanic DataFrame.

titanic_select = titanic[["name","sex","age", "survived" ]]
titanic_select.head()
# Out:
#                                               name     sex      age  survived
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000         1
# 1                   Allison, Master. Hudson Trevor    male   0.9167         1
# 2                     Allison, Miss. Helen Loraine  female   2.0000         0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000         0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000         0

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# Note – you may see people selecting columns using dataframe.column_name
#
# This is legal – but not good practice!

# %%
# This will work - but is not good practice!

titanic.sex.head()
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %% [markdown]
# We don’t recommend this because it looks too much like an attribute or method.
#
# This also won’t work if you had a column that was something like `mean` as Python can’t determine if you mean the column `mean` or the method `.mean()`.
#
# There’s no ambiguity with
#
# ``` python
# dataframe[“column”]
# ```
# which is why we will always recommend it over the `dataframe.column_name`

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ## Selecting on data type
# We can also use the method `.select_dtypes()` if we want to include or exclude specific kinds of data from our dataframe.

# %%
# Select just the object columns
animal_object_cols = animals.select_dtypes(exclude=["object"])

# Return the top of the animal columns

animal_object_cols.head()
# Out:
#    CalYear  PumpCount  PumpHoursTotal  HourlyNominalCost(£)  \
# 0     2009        1.0             2.0                   255
# 1     2009        1.0             1.0                   255
# 2     2009        1.0             1.0                   255
# 3     2009        1.0             1.0                   255
# 4     2009        1.0             1.0                   255
#
#    IncidentNominalCost(£)
# 0                   510.0
# 1                   255.0
# 2                   255.0
# 3                   255.0
# 4                   255.0

# %% [markdown]
# We must specify our include data types as a list here, even if we’re just specifying one value. It’s just the way this function was written.
#
# * “object” includes our string columns, I could also use "O" here.
# * "float64” and “int64” will select floating point numbers and integer numbers.
# * If you have the numpy package loaded ( import numpy as np) you can use np.number (no quotes) to return numerical data.
#
# You can also use the parameter `exclude=` which may be easier if you wish to omit just one data type.

# %% [markdown]
# [return to menu](#menu)

# %% [markdown]
# <a id='filter'></a>
# <hr style="width:100%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:1">

# %% [markdown]
# ## Filtering

# %% [markdown]
# We can achieve really simple filtering by passing a range to the DataFrame indexer.
#
# e.g.

# %%
animals[0:5]
# Out:
#   IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0         139091  01/01/2009 03:01     2009  2008/09  Special Service
# 1         275091  01/01/2009 08:51     2009  2008/09  Special Service
# 2        2075091  04/01/2009 10:07     2009  2008/09  Special Service
# 3        2872091  05/01/2009 12:27     2009  2008/09  Special Service
# 4        3553091  06/01/2009 15:23     2009  2008/09  Special Service
#
#    PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 0        1.0             2.0                   255                   510.0
# 1        1.0             1.0                   255                   255.0
# 2        1.0             1.0                   255                   255.0
# 3        1.0             1.0                   255                   255.0
# 4        1.0             1.0                   255                   255.0
#
#                             FinalDescription AnimalGroupParent  \
# 0  DOG WITH JAW TRAPPED IN MAGAZINE RACK,B15               Dog
# 1          ASSIST RSPCA WITH FOX TRAPPED,B15               Fox
# 2                    DOG CAUGHT IN DRAIN,B15               Dog
# 3                  HORSE TRAPPED IN LAKE,J17             Horse
# 4              RABBIT TRAPPED UNDER SOFA,B15            Rabbit
#
#                                     PropertyType  \
# 0                      House - single occupancy
# 1                                       Railings
# 2                                 Pipe or drain
# 3  Intensive Farming Sheds (chickens, pigs etc)
# 4                      House - single occupancy
#
#         SpecialServiceTypeCategory  \
# 0          Other animal assistance
# 1          Other animal assistance
# 2  Animal rescue from below ground
# 3         Animal rescue from water
# 4          Other animal assistance
#
#                                   SpecialServiceType     Borough  \
# 0  Animal assistance involving livestock - Other ...     Croydon
# 1  Animal assistance involving livestock - Other ...     Croydon
# 2     Animal rescue from below ground - Domestic pet      Sutton
# 3             Animal rescue from water - Farm animal  Hillingdon
# 4  Animal assistance involving livestock - Other ...    Havering
#
#   StnGroundName AnimalClass  Code        London
# 0       Norbury      Mammal  00AH  Outer London
# 1      Woodside      Mammal  00AH  Outer London
# 2    Wallington      Mammal  00BF  Outer London
# 3       Ruislip      Mammal  00AS  Outer London
# 4   Harold Hill      Mammal  00AR  Outer London

# %% [markdown]
# Which returns us the same rows as `.head()`. We can however modify this to return any range of rows within the DataFrame we like - for example the middle of our DataFrame.

# %%
animals[200:250]
# Out:
#     IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 200       81770091  15/05/2009 16:50     2009  2009/10  Special Service
# 201       82208091  16/05/2009 13:20     2009  2009/10  Special Service
# 202       82239091  16/05/2009 14:28     2009  2009/10  Special Service
# 203       82314091  16/05/2009 17:09     2009  2009/10  Special Service
# 204       82769091  17/05/2009 09:54     2009  2009/10  Special Service
# 205       83410091  18/05/2009 13:44     2009  2009/10  Special Service
# 206       83903091  19/05/2009 10:38     2009  2009/10  Special Service
# 207       83922091  19/05/2009 11:35     2009  2009/10  Special Service
# 208       84125091  19/05/2009 17:46     2009  2009/10  Special Service
# 209       84176091  19/05/2009 19:07     2009  2009/10  Special Service
# 210       84307091  20/05/2009 00:18     2009  2009/10  Special Service
# 211       84523091  20/05/2009 11:36     2009  2009/10  Special Service
# 212       85725091  22/05/2009 10:30     2009  2009/10  Special Service
# 213       85961091  22/05/2009 16:24     2009  2009/10  Special Service
# 214       86422091  23/05/2009 06:21     2009  2009/10  Special Service
# 215       87224091  24/05/2009 10:18     2009  2009/10  Special Service
# 216       87402091  24/05/2009 14:53     2009  2009/10  Special Service
# 217       87493091  24/05/2009 16:46     2009  2009/10  Special Service
# 218       89326091  27/05/2009 08:42     2009  2009/10  Special Service
# 219       89957091  28/05/2009 11:11     2009  2009/10  Special Service
# 220       90144091  28/05/2009 17:20     2009  2009/10  Special Service
# 221       90706091  29/05/2009 12:24     2009  2009/10  Special Service
# 222       90806091  29/05/2009 15:19     2009  2009/10  Special Service
# 223       92294091  31/05/2009 14:28     2009  2009/10  Special Service
# 224       92335091  31/05/2009 15:52     2009  2009/10  Special Service
# 225       92987091  01/06/2009 14:14     2009  2009/10  Special Service
# 226       93306091  01/06/2009 19:49     2009  2009/10  Special Service
# 227       93409091  01/06/2009 21:43     2009  2009/10  Special Service
# 228       93474091  01/06/2009 23:58     2009  2009/10  Special Service
# 229       93633091  02/06/2009 10:12     2009  2009/10  Special Service
# 230       93664091  02/06/2009 11:15     2009  2009/10  Special Service
# 231       93755091  02/06/2009 13:28     2009  2009/10  Special Service
# 232       93771091  02/06/2009 13:49     2009  2009/10  Special Service
# 233       93925091  02/06/2009 16:50     2009  2009/10  Special Service
# 234       94505091  03/06/2009 11:03     2009  2009/10  Special Service
# 235       94526091  03/06/2009 12:03     2009  2009/10  Special Service
# 236       94847091  03/06/2009 21:28     2009  2009/10  Special Service
# 237       95289091  04/06/2009 16:17     2009  2009/10  Special Service
# 238       95595091  04/06/2009 21:37     2009  2009/10  Special Service
# 239       96023091  05/06/2009 17:39     2009  2009/10  Special Service
# 240       96063091  05/06/2009 18:10     2009  2009/10  Special Service
# 241       96083091  05/06/2009 18:37     2009  2009/10  Special Service
# 242       96737091  06/06/2009 19:29     2009  2009/10  Special Service
# 243       96751091  06/06/2009 20:03     2009  2009/10  Special Service
# 244       97181091  07/06/2009 10:24     2009  2009/10  Special Service
# 245       97816091  08/06/2009 14:25     2009  2009/10  Special Service
# 246       98231091  09/06/2009 08:37     2009  2009/10  Special Service
# 247       98345091  09/06/2009 13:26     2009  2009/10  Special Service
# 248       98378091  09/06/2009 14:19     2009  2009/10  Special Service
# 249       99402091  11/06/2009 13:28     2009  2009/10  Special Service
#
#      PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 200        1.0             1.0                   260                   260.0
# 201        1.0             1.0                   260                   260.0
# 202        1.0             1.0                   260                   260.0
# 203        1.0             1.0                   260                   260.0
# 204        1.0             1.0                   260                   260.0
# 205        1.0             4.0                   260                  1040.0
# 206        1.0             1.0                   260                   260.0
# 207        1.0             1.0                   260                   260.0
# 208        1.0             1.0                   260                   260.0
# 209        1.0             1.0                   260                   260.0
# 210        1.0             1.0                   260                   260.0
# 211        1.0             1.0                   260                   260.0
# 212        1.0             1.0                   260                   260.0
# 213        1.0             1.0                   260                   260.0
# 214        1.0             1.0                   260                   260.0
# 215        1.0             1.0                   260                   260.0
# 216        1.0             2.0                   260                   520.0
# 217        1.0             1.0                   260                   260.0
# 218        1.0             1.0                   260                   260.0
# 219        1.0             1.0                   260                   260.0
# 220        1.0             1.0                   260                   260.0
# 221        1.0             1.0                   260                   260.0
# 222        1.0             1.0                   260                   260.0
# 223        1.0             1.0                   260                   260.0
# 224        1.0             1.0                   260                   260.0
# 225        1.0             1.0                   260                   260.0
# 226        1.0             1.0                   260                   260.0
# 227        1.0             1.0                   260                   260.0
# 228        1.0             1.0                   260                   260.0
# 229        1.0             1.0                   260                   260.0
# 230        1.0             1.0                   260                   260.0
# 231        1.0             1.0                   260                   260.0
# 232        1.0             1.0                   260                   260.0
# 233        1.0             1.0                   260                   260.0
# 234        1.0             1.0                   260                   260.0
# 235        1.0             1.0                   260                   260.0
# 236        1.0             1.0                   260                   260.0
# 237        1.0             1.0                   260                   260.0
# 238        1.0             1.0                   260                   260.0
# 239        1.0             1.0                   260                   260.0
# 240        1.0             1.0                   260                   260.0
# 241        1.0             1.0                   260                   260.0
# 242        1.0             1.0                   260                   260.0
# 243        1.0             1.0                   260                   260.0
# 244        1.0             1.0                   260                   260.0
# 245        1.0             1.0                   260                   260.0
# 246        1.0             1.0                   260                   260.0
# 247        1.0             1.0                   260                   260.0
# 248        1.0             3.0                   260                   780.0
# 249        1.0             1.0                   260                   260.0
#
#                                       FinalDescription  \
# 200                             CAT STUCK ON FENCE,B15
# 201                          DOG TRAPPED UNDER CAR,B15
# 202                           ROAD TRAFFIC ACCIDENT,B1
# 203                          DOG STUCK IN FOX HOLE,B15
# 204                        CAT STUCK BEHIND TOILET,B15
# 205    ASSIST RSPCA WITH PIGEON TRAPPED IN CHIMNEY,B15
# 206  ASSIST RSPCA WITH 2  DUCKLINGS TRAPPED BEWTEEN...
# 207                                  ASSIST RSPCA, B15
# 208                ASSIST RSPCA WITH CAT UP A TREE,B15
# 209  G561 RUNNING CALL TO PIGEON TRAPPED IN NETTING...
# 210               KITTEN STUCK UNDER FLOORBOARDS  ,B15
# 211  SMALL ANIMAL RESCUE - BIRD TRAPPED BETWEEN WAL...
# 212                          BIRD STUCK IN NETTING,B15
# 213                     BIRD TRAPPED IN NETTING,B15,RC
# 214                    CAT STUCK BETWEEN TWO WALLS,B15
# 215               ANIMAL TRAPPED IN CHIMNEY BREAST,B15
# 216                              HORSE IN AQUEDUCT,J17
# 217                         DOG CAUGHT IN BRAMBLES,B15
# 218                         CAT TRAPPED UNDER SHED,B15
# 219    TWO HORSES FALLEN DOWN BANK AND INTO CANAL, J17
# 220                          BIRD STUCK IN CHIMNEY,B15
# 221   PUPPY WITH HEAD STUCK IN FRONT IRON GATE    ,B15
# 222                 ASSIST RSPCA WITH INJURED BIRDS,B2
# 223                UNKNOWN ANIMAL STUCK IN CHIMNEY,B15
# 224                              CAT STUCK ON ROOF,B15
# 225                  SQUIRREL TRAPPED IN GUTTERING,B15
# 226      CAT STUCK UP TREE BEING ATTACKED BY BIRDS,B15
# 227                    CAT STUCK IN CONTAINER, B15, RC
# 228                DOG TRAPPED AT REAR OF PROPERTY,B15
# 229      DOG TRAPPED BEHIND RAILWAY LINE AND FENCE,B15
# 230                  ASSIST RSPCA WITH CAT UP TREE,B15
# 231    ASSIST RSPCA OFFICER WITH CAT STUCK UP TREE,B15
# 232                                  BIRD TRAPPED, B15
# 233                                   ASSIST RSPCA,B15
# 234            ASSIST RSPCA WITH CAT STUCK UP TREE,B15
# 235                        DOG TRAPPED IN CAT FLAP,B15
# 236              DOG WITH HEAD TRAPPED IN RAILINGS,B15
# 237                        BIRD TRAPPED IN CHIMNEY,B15
# 238                                   ASSIST RSPCA,B15
# 239                          CAT TRAPPED IN GARDEN,B15
# 240                      PIGEON TRAPPED IN NETTING,B15
# 241                     PIGEONS TRAPPED IN NETTING,B15
# 242                  ASSIST RSPCA WITH DOG ON ROOF,B15
# 243                            SMALL ANIMAL RESCUE,B15
# 244       KITTEN WITH HEAD TRAPPED BEHIND CUPBOARD,B15
# 245  ASSIST RSPCA WITH PIGEONS TRAPPED IN NETTING, B15
# 246                KITTENS STUCK UNDER FLOORBOARDS,B15
# 247                       CAT STUCK BETWEEN WALLS, B15
# 248                          PUPPY STUCK IN DRAIN, B15
# 249            ASSIST RSPCA WITH CAT STUCK IN TREE,B15
#
#                     AnimalGroupParent  \
# 200                               Cat
# 201                               Dog
# 202                               Dog
# 203                               Dog
# 204                               Cat
# 205                              Bird
# 206                              Bird
# 207                              Bird
# 208                               Cat
# 209                              Bird
# 210                               Cat
# 211                              Bird
# 212                              Bird
# 213                              Bird
# 214                               Cat
# 215                              Bird
# 216                             Horse
# 217                               Dog
# 218                               Cat
# 219                             Horse
# 220                              Bird
# 221                               Dog
# 222                              Bird
# 223  Unknown - Domestic Animal Or Pet
# 224                               Cat
# 225                          Squirrel
# 226                               Cat
# 227                               Cat
# 228                               Dog
# 229                               Dog
# 230                               Cat
# 231                               Cat
# 232                              Bird
# 233                              Bird
# 234                               Cat
# 235                               Cat
# 236                               Dog
# 237                              Bird
# 238             Unknown - Wild Animal
# 239                               Cat
# 240                              Bird
# 241                              Bird
# 242                               Dog
# 243  Unknown - Heavy Livestock Animal
# 244                               Cat
# 245                              Bird
# 246                               Cat
# 247                               Cat
# 248                               Dog
# 249                               Cat
#
#                                           PropertyType  \
# 200                                             Bridge
# 201                                               Car
# 202                                               Car
# 203        Domestic garden (vegetation not equipment)
# 204  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 205                          House - single occupancy
# 206                              Multi-Storey car park
# 207                                             Bridge
# 208        Domestic garden (vegetation not equipment)
# 209                            Vehicle Repair Workshop
# 210     Converted Flat/Maisonettes - 3 or more storeys
# 211                          House - single occupancy
# 212  Purpose Built Flats/Maisonettes - Up to 3 stor...
# 213                                        Tree scrub
# 214                                    Private garage
# 215                          House - single occupancy
# 216                                       River/canal
# 217                                              Park
# 218                          House - single occupancy
# 219                   Grassland, pasture, grazing etc
# 220                          House - single occupancy
# 221                          House - single occupancy
# 222  Purpose Built Flats/Maisonettes - Up to 3 stor...
# 223  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 224                          House - single occupancy
# 225                          House - single occupancy
# 226                                        Tree scrub
# 227                                         Wasteland
# 228        Domestic garden (vegetation not equipment)
# 229                      Railway trackside vegetation
# 230                          House - single occupancy
# 231              Woodland/forest - broadleaf/hardwood
# 232                                              Park
# 233                          House - single occupancy
# 234        Domestic garden (vegetation not equipment)
# 235                          House - single occupancy
# 236                                           Railings
# 237                          House - single occupancy
# 238                          House - single occupancy
# 239                          House - single occupancy
# 240                                 Large supermarket
# 241                                 Large supermarket
# 242       Converted Flat/Maisonette - Up to 2 storeys
# 243                                      Fire station
# 244                          House - single occupancy
# 245                                    Restaurant/cafe
# 246                          House - single occupancy
# 247  Purpose Built Flats/Maisonettes - Up to 3 stor...
# 248                          House - single occupancy
# 249                          House - single occupancy
#
#           SpecialServiceTypeCategory  \
# 200        Animal rescue from height
# 201          Other animal assistance
# 202          Other animal assistance
# 203  Animal rescue from below ground
# 204  Animal rescue from below ground
# 205        Animal rescue from height
# 206  Animal rescue from below ground
# 207        Animal rescue from height
# 208        Animal rescue from height
# 209        Animal rescue from height
# 210  Animal rescue from below ground
# 211          Other animal assistance
# 212        Animal rescue from height
# 213        Animal rescue from height
# 214          Other animal assistance
# 215  Animal rescue from below ground
# 216         Animal rescue from water
# 217        Animal rescue from height
# 218  Animal rescue from below ground
# 219         Animal rescue from water
# 220          Other animal assistance
# 221          Other animal assistance
# 222        Animal rescue from height
# 223        Animal rescue from height
# 224        Animal rescue from height
# 225        Animal rescue from height
# 226        Animal rescue from height
# 227  Animal rescue from below ground
# 228          Other animal assistance
# 229          Other animal assistance
# 230        Animal rescue from height
# 231        Animal rescue from height
# 232        Animal rescue from height
# 233        Animal rescue from height
# 234        Animal rescue from height
# 235          Other animal assistance
# 236          Other animal assistance
# 237        Animal rescue from height
# 238         Animal rescue from water
# 239          Other animal assistance
# 240        Animal rescue from height
# 241        Animal rescue from height
# 242        Animal rescue from height
# 243          Other animal assistance
# 244          Other animal assistance
# 245        Animal rescue from height
# 246  Animal rescue from below ground
# 247        Animal rescue from height
# 248  Animal rescue from below ground
# 249        Animal rescue from height
#
#                                     SpecialServiceType  \
# 200           Animal rescue from height - Domestic pet
# 201    Animal assistance - Lift heavy livestock animal
# 202  Animal assistance involving livestock - Other ...
# 203     Animal rescue from below ground - Domestic pet
# 204     Animal rescue from below ground - Domestic pet
# 205                   Animal rescue from height - Bird
# 206             Animal rescue from below ground - Bird
# 207                   Animal rescue from height - Bird
# 208           Animal rescue from height - Domestic pet
# 209                   Animal rescue from height - Bird
# 210     Animal rescue from below ground - Domestic pet
# 211  Animal assistance involving livestock - Other ...
# 212                   Animal rescue from height - Bird
# 213                   Animal rescue from height - Bird
# 214  Animal assistance involving livestock - Other ...
# 215             Animal rescue from below ground - Bird
# 216             Animal rescue from water - Farm animal
# 217           Animal rescue from height - Domestic pet
# 218     Animal rescue from below ground - Domestic pet
# 219             Animal rescue from water - Farm animal
# 220  Animal assistance involving livestock - Other ...
# 221  Animal assistance involving livestock - Other ...
# 222                   Animal rescue from height - Bird
# 223           Animal rescue from height - Domestic pet
# 224           Animal rescue from height - Domestic pet
# 225                     Wild animal rescue from height
# 226           Animal rescue from height - Domestic pet
# 227     Animal rescue from below ground - Domestic pet
# 228  Animal assistance involving livestock - Other ...
# 229  Animal assistance involving livestock - Other ...
# 230           Animal rescue from height - Domestic pet
# 231           Animal rescue from height - Domestic pet
# 232                   Animal rescue from height - Bird
# 233                   Animal rescue from height - Bird
# 234           Animal rescue from height - Domestic pet
# 235  Animal assistance involving livestock - Other ...
# 236  Animal assistance involving livestock - Other ...
# 237                   Animal rescue from height - Bird
# 238               Wild animal rescue from water or mud
# 239  Animal assistance involving livestock - Other ...
# 240                   Animal rescue from height - Bird
# 241                   Animal rescue from height - Bird
# 242           Animal rescue from height - Domestic pet
# 243  Animal assistance involving livestock - Other ...
# 244  Animal assistance involving livestock - Other ...
# 245                   Animal rescue from height - Bird
# 246     Animal rescue from below ground - Domestic pet
# 247           Animal rescue from height - Domestic pet
# 248     Animal rescue from below ground - Domestic pet
# 249           Animal rescue from height - Domestic pet
#
#                     Borough    StnGroundName AnimalClass  Code        London
# 200           Tower Hamlets    Bethnal Green      Mammal  00BG  Outer London
# 201                   Brent   West Hampstead      Mammal  00AE  Outer London
# 202                 Bromley        Orpington      Mammal  00AF  Outer London
# 203               Redbridge         Hainault      Mammal  00BC  Outer London
# 204                 Croydon        Addington      Mammal  00AH  Outer London
# 205               Redbridge           Ilford        Bird  00BC  Outer London
# 206              Hillingdon       Hillingdon        Bird  00AS  Outer London
# 207                 Enfield          Enfield        Bird  00AK  Outer London
# 208                  Ealing           Ealing      Mammal  00AJ  Outer London
# 209              Hillingdon         Heathrow        Bird  00AS  Inner London
# 210                  Camden   West Hampstead      Mammal  00AG  Outer London
# 211    Barking And Dagenham         Dagenham        Bird  00AB  Outer London
# 212                  Barnet           Barnet        Bird  00AC  Outer London
# 213    Kingston Upon Thames         Kingston        Bird  00AX  Outer London
# 214                  Bexley           Bexley      Mammal  00AD  Outer London
# 215                 Enfield         Edmonton        Bird  00AK  Outer London
# 216          Waltham Forest      Walthamstow      Mammal  00BH  Outer London
# 217          Waltham Forest        Chingford      Mammal  00BH  Outer London
# 218                  Barnet         Finchley      Mammal  00AC  Outer London
# 219          Waltham Forest      Walthamstow      Mammal  00BH  Outer London
# 220    Barking And Dagenham         Dagenham        Bird  00AB  Outer London
# 221               Greenwich   East Greenwich      Mammal  00AL  Inner London
# 222                Lewisham          Bromley        Bird  00AZ  Inner London
# 223              Wandsworth       Wandsworth      Mammal  00BJ  Outer London
# 224                  Merton        Wimbledon      Mammal  00BA  Outer London
# 225          Waltham Forest        Chingford      Mammal  00BH  Outer London
# 226                 Enfield          Enfield      Mammal  00AK  Inner London
# 227           Tower Hamlets         Shadwell      Mammal  00BG  Outer London
# 228                  Bexley           Eltham      Mammal  00AD  Inner London
# 229                 Hackney  Stoke Newington      Mammal  00AM  Outer London
# 230                 Bromley          Bromley      Mammal  00AF  Outer London
# 231                  Ealing           Ealing      Mammal  00AJ  Inner London
# 232                Lewisham        Greenwich        Bird  00AZ  Outer London
# 233                  Barnet         Finchley        Bird  00AC  Outer London
# 234                 Bromley          Bromley      Mammal  00AF  Outer London
# 235          Waltham Forest      Walthamstow      Mammal  00BH  Outer London
# 236              Hillingdon            Hayes      Mammal  00AS  Outer London
# 237                 Croydon          Croydon        Bird  00AH  Outer London
# 238                   Brent        Willesden      Mammal  00AE  Inner London
# 239  Hammersmith And Fulham           Fulham      Mammal  00AN  Outer London
# 240    Kingston Upon Thames         Kingston        Bird  00AX  Outer London
# 241    Kingston Upon Thames         Kingston        Bird  00AX  Outer London
# 242               Redbridge           Ilford      Mammal  00BC  Outer London
# 243                 Croydon          Croydon      Mammal  00AH  Inner London
# 244                Lewisham          Bromley      Mammal  00AZ  Outer London
# 245                 Enfield          Enfield        Bird  00AK  Inner London
# 246                  Newham         Plaistow      Mammal  00BB  Inner London
# 247               Southwark         Dockhead      Mammal  00BE  Outer London
# 248                  Ealing         Southall      Mammal  00AJ  Outer London
# 249                 Croydon          Croydon      Mammal  00AH  Inner London

# %% [markdown]
# However we can do more involved, conditional filtering using `pandas`.

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Single Conditional Filtering

# %% [markdown]
# Pandas filters data in a two step process.
#
# 1.	It creates a `mask` that specifies inclusion or exclusion for each row in the DataFrame.
# 2.	Apply the mask on to the DataFrame to return the subset of rows that are included.
#
# In the code below I will create a few simple DataFrames to illustrate my point. Don’t worry too much about how these bits of code works; as previously mentioned you’ll often be working with much larger DataFrames that you’ll load in using one of the `pd.read_` commands.

# %%
# Let's create a simple DataFrame to look at this in practice
# Again, you don't need to worry about how this works

cat_dog = pd.DataFrame({"animal": ["Cat", "Cat", "Dog", "Cat"] , 
                        "name": ["Catalie Portman","Pico de Gato", "Chewbarka", "JK Meowling"]})

# Print out the DataFrame

cat_dog
# Out:
#   animal             name
# 0    Cat  Catalie Portman
# 1    Cat     Pico de Gato
# 2    Dog        Chewbarka
# 3    Cat      JK Meowling

# %% [markdown]
# I want to filter so I just have ‘Cat’ Rows.
#
# My condition can be written like this:

# %%
mask = cat_dog['animal'] == 'Cat'

# %% [markdown]
# * I am assigning my output to the variable `mask` with the single = sign
# * The column I want to look for values in is `"animal"` from the `catdog` Dataframe - `catdog["animal"]`
# * From that column I want to find values that meet my condition – I state this with the double equals `==`
# * Finally I am telling Pandas what value I want to find; a string containing “Cat”
#
# If we run the cell we can see the output is a Boolean Series, our True and False values.

# %%
# Run me to see the Series of Boolean values
mask
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# Name: animal, dtype: bool

# %% [markdown]
# Here I’ve added displayed this series as a new column on our `cat_dog` DataFrame to demonstrate.
#
# | index  | animal  |       name      | included |
# |:-:|:-------:|:---------------:|----------|
# | 0 |   Cat   | Catalie Portman | True     |
# | 1 |   Cat   |   Pico de Gato  | True     |
# | 2 |   Dog   |    Chewbarka    | False    |
# | 3 |   Cat   |   JK Meowling   | True     |
#
# We can see where the value in the `animal` column was `"Cat"`; the `mask` column is `True`.
#
# Where the value was not cat (e.g `"Dog"`) the `mask` column is `False`.
#
# However I want to return just the rows where the value in `mask` was `True`.
#
# To do this we apply the `mask` variable on to the `cat_dog` Dataframe using our indexing or selection brackets.

# %%
just_cats = cat_dog[mask]
just_cats
# Out:
#   animal             name
# 0    Cat  Catalie Portman
# 1    Cat     Pico de Gato
# 3    Cat      JK Meowling

# %% [markdown]
# This will only return the rows where our conditional filter equated to `True`.
#
# Rather than create and apply a mask seperately we can do the whole filter operation in one step:

# %%
just_cats = cat_dog[  cat_dog['animal'] == "Cat"]
just_cats
# Out:
#   animal             name
# 0    Cat  Catalie Portman
# 1    Cat     Pico de Gato
# 3    Cat      JK Meowling

# %% [markdown]
# You’ll notice the cell with the “Dog” value has been dropped.
#
# You’ll also notice that our index has not changed. You will sometimes want to reset the index after filtering to restore  it to sequential integers starting at 0.
#
# You can do this like so.

# %%
just_cats.reset_index(drop=True, inplace=True)
just_cats
# Out:
#   animal             name
# 0    Cat  Catalie Portman
# 1    Cat     Pico de Gato
# 2    Cat      JK Meowling

# %% [markdown]
# By default the previous column index is put in as a new column. By using `drop=True` we can remove this behaviour.
#
# `inplace=True` updates the DataFrame in place and is an alternative to overwriting the data with
#
# `just_cats = just_cats.reset_index(drop=True) `

# %% [markdown]
# Our logical comparison statements are:
#
#
# | Symbol | Meaning|
# |------------|------------|
# | ==       | Is equivalent to|
# | !=| Does not equal|
# |> |Greater than|
# |>=| Greater than or equivalent too|
# |< |Less than|
# |<= |Less than or equivalent too|
#
#
#
# Let’s view one more example – using our animals **DataFrame**  to find `IncidentNominalCost(£)` over £1000.

# %%
# Note here we're using the animals DataFrame

cost_over_1k = animals[ animals['IncidentNominalCost(£)'] > 1000 ]
cost_over_1k = cost_over_1k.reset_index()
cost_over_1k.head()

# %% [markdown]
# Here we have
# * Assigned a new name `cost_over_1k` which will hold our output
# * Give our DataFrame name, and our indexing or selection brackets:  `animals[]`
# * The column I want to look for values in is ”IncidentNominalCost” from the Animals Dataframe `animals[‘IncidentNominalCost(£)’]`
# * The condition I want is ` > 1000` , greater than a thousand. As this is a numeric column I can just specify the number.
# * Printing out the variable, using `.sample(6)` method to display 6 rows of the new DataFrame.

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise 1
#
# Filter the `titanic` DataFrame by `sex` column; return the “female” values.

# %%
# Exercise

# %%
# %load ../solutions/chapter_4/titanic_filter_one.py
# Filter the `titanic` DataFrame by `sex` column; return the “female” values.

titanic_female = titanic[titanic['sex'] ==  "female"]
titanic_female.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
#
#     age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0      0      0   24160  211.3375       B5        S
# 2   2.0      1      2  113781  151.5500  C22 C26        S
# 4  25.0      1      2  113781  151.5500  C22 C26        S
# 6  63.0      1      0   13502   77.9583       D7        S
# 8  53.0      2      0   11769   51.4792     C101        S
#
#                          home.dest  body boat
# 0                     St Louis, MO   NaN    2
# 2  Montreal, PQ / Chesterville, ON   NaN  NaN
# 4  Montreal, PQ / Chesterville, ON   NaN  NaN
# 6                       Hudson, NY   NaN   10
# 8              Bayside, Queens, NY   NaN    D

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise 2
#
# Filter the `titanic` DataFrame by `age` column; return the values over 40.

# %%
# Exercise

# %%
# %load ../solutions/chapter_4/titanic_filter_two.py
# Filter the titanic DataFrame by age column; return the values over 40.

titanic_over40 = titanic[titanic['age'] > 40]
titanic_over40.head()
# Out:
#     pclass  survived                                           name     sex  \
# 5        1         1                            Anderson, Mr. Harry    male
# 6        1         1              Andrews, Miss. Kornelia Theodosia  female
# 8        1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9        1         0                        Artagaveytia, Mr. Ramon    male
# 10       1         0                         Astor, Col. John Jacob    male
#
#      age  sibsp  parch    ticket      fare    cabin embarked  \
# 5   48.0      0      0     19952   26.5500      E12        S
# 6   63.0      1      0     13502   77.9583       D7        S
# 8   53.0      2      0     11769   51.4792     C101        S
# 9   71.0      0      0  PC 17609   49.5042      NaN        C
# 10  47.0      1      0  PC 17757  227.5250  C62 C64        C
#
#               home.dest   body boat
# 5          New York, NY    NaN    3
# 6            Hudson, NY    NaN   10
# 8   Bayside, Queens, NY    NaN    D
# 9   Montevideo, Uruguay   22.0  NaN
# 10         New York, NY  124.0  NaN

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise 3
#
# Filter the `titanic` DataFrame by `fare` column; return the values less than or equal to 30.50 .

# %%
# Exercise

# %%
# Solution - These cells contain answers for the exercises.
# Run once to reveal the code
# Run again to reveal the output

# %load ../solutions/chapter_4/titanic_filter_three.py

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Multiple Conditional Filtering

# %% [markdown]
# Just as we can filter by one condition we can also filter by multiple conditions.
#
# Let’s add in a new column, representing age to the `cat_dog` DataFrame.

# %%
# Let's create a simple DataFrame to look at this in practice
# Again, we don't need to worry about how we do this!

cat_dog = pd.DataFrame({"animal": ["Cat", "Cat", "Dog", "Cat", "Dog"], 
                        "name": ["Catalie Portman","Pico de Gato", "Chewbarka", "JK Meowling", "K9"],
                        "age": [3, 5, 1, 7, 11]}, 
                       columns=["name", "animal", "age"])


# Print out the DataFrame

cat_dog
# Out:
#               name animal  age
# 0  Catalie Portman    Cat    3
# 1     Pico de Gato    Cat    5
# 2        Chewbarka    Dog    1
# 3      JK Meowling    Cat    7
# 4               K9    Dog   11

# %% [markdown]
# We now have an age column, and we’ll be able to select on more than one condition.
#
# When we want to filter on more than one condition, we have to consider how those conditions relate to each other.
#
# AND relationships use the & symbol (Shift and 7 on the keyboard) and require **both** or **all** conditions to evaluate to `True`.
#
# OR relationships use the | symbol (Shift and `\` or ALT 124 on a numerical keypad) and require **one** of the conditions to evaluate to `True`
#
# Below is a “Truth table” that can be handy as a look up.
#
#
# | Condition 1 | Condition 2  | & (AND) Equates to |  &#124; (OR) Equates to |
# |:-----------:|:------------:|:------------------:|:------------------:|
# |     True    |     True     |        True        |        True        |
# |     True    |     False    |        False       |        True        |
# |    False    |     True     |        False       |        True        |
# |    False    |     False    |        False       |        False       |
#
# Note that both conditions must evaluate to `True` in order for it to evaluate to `True` overall.

# %% [markdown]
# We now have an age column so we can now select all Cats that are older than 4.
#
# Again, in this example we will create a mask so we can see what Boolean values are happening behind the scenes.

# %%
# Create my mask
mask = (cat_dog['animal'] == "Cat") & (cat_dog['age'] > 4)

# have a look at the mask
mask
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool

# %% [markdown]
# * I am assigning my output to the variable `mask` with a single = sign.
#
#
# * My first conditional statement:
#     * Has round brackets surrounding it `(`
#     * The first column I want to look for values in is `"animal"` from the `catdog` Dataframe - `catdog[“animal”]`
#     * From that column I want to find values that meet my condition – I state this with the double equals `==`
#     * Finally I am telling `pandas` what value I want to find; a string containing “Cat”
#     * My first condition complete I close my round brackets `)`
#
#
# * I use a symbol to represent the relationship between my conditons. Here an ampersand - `&` (Shift and 7) is used to represent `AND`
#
#
# * My second conditional statement:
#     * Has round brackets surrounding it `(`
#     * The first column I want to look for values in is `"age"` from the `catdog` Dataframe - `catdog[“age”]`
#     * From that column I want to find values that are greater than my condition – I state this with the  `>`
#     * Finally I am telling Pandas what value I want to find; an int 4
#     * My second condition complete I close my round brackets `)`
#
#
# Let's look at the `mask` values alongside the DataFrame:
#
# | index  | animal  |       name      | age | included |
# |:-:|:-------:|:---------------:|-----|----------|
# | 0 |   Cat   | Catalie Portman | 3   | False    |
# | 1 |   Cat   |   Pico de Gato  | 5   | True     |
# | 2 |   Dog   |    Chewbarka    | 1   | False    |
# | 3 |   Cat   |   JK Meowling   | 7   | True     |
# | 4 | Dog     | K9              | 11  | False    |

# %% [markdown]
# And when we apply the mask to the DataFrame we can see the filtered Dataframe - with only Cats over 4.

# %%
cats_over_4 = cat_dog[mask]
cats_over_4
# Out:
#            name animal  age
# 1  Pico de Gato    Cat    5
# 3   JK Meowling    Cat    7

# %% [markdown]
# We can of course do this in one line as well.
#
# We reference the DataFrame we are selecting from, and then place our filter condition within the indexing or selection brackets.

# %%
cats_over_4 = cat_dog[  (cat_dog["animal"] == "Cat") & (cat_dog["age"] > 4)     ]
cats_over_4
# Out:
#            name animal  age
# 1  Pico de Gato    Cat    5
# 3   JK Meowling    Cat    7

# %% [markdown]
# If we can use the AND condition (&) we can also use the OR condition where only one of the conditions must be met to evaluate to `True`.
#
# The OR condition is represented by a vertical bar symbol ( `|` ) – press shift and `\`.
#
# Lets add a condition where the animal is a cat **OR** the age is greater than 4.

# %%
# Create my mask
mask = (cat_dog["animal"] == "Cat") | (cat_dog["age"] > 4)

# View mask

mask
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# dtype: bool

# %% [markdown]
# Let's look at the `mask` values alongside the DataFrame:
#
# | index  | animal  |       name      | age | included |
# |:-:|:-------:|:---------------:|-----|----------|
# | 0 |   Cat   | Catalie Portman | 3   | True     |
# | 1 |   Cat   |   Pico de Gato  | 5   | True     |
# | 2 |   Dog   |    Chewbarka    | 1   | False    |
# | 3 |   Cat   |   JK Meowling   | 7   | True     |
# | 4 | Dog     | K9              | 11  | True     |
#
# Catalie Portman now evaluates to True. While she is younger than 3 she is a Cat – and by meeting one of the conditions is included.
#
# K9 also evaluates to `True`. He is not a cat; but meets the age condition by being older than 4 and so is included.
#
# We can of course apply this mask to filter the DataFrame

# %%
cats_or_over4 = cat_dog[mask]
cats_or_over4
# Out:
#               name animal  age
# 0  Catalie Portman    Cat    3
# 1     Pico de Gato    Cat    5
# 3      JK Meowling    Cat    7
# 4               K9    Dog   11

# %% [markdown]
# Or do the whole action in one line of code.

# %%
cats_or_over4 = cat_dog[(cat_dog["animal"] == "Cat") | (cat_dog["age"] > 4)]
cats_or_over4
# Out:
#               name animal  age
# 0  Catalie Portman    Cat    3
# 1     Pico de Gato    Cat    5
# 3      JK Meowling    Cat    7
# 4               K9    Dog   11

# %% [markdown]
# Here are some more examples using the `titanic` DataFrame.
#
# Here we are filtering for survivors (value 1), who were female. Using an AND (&) condition

# %%
female_survivors = titanic[(titanic["survived"] == 1) & (titanic["sex"] == "female")]
female_survivors.tail()
# Out:
#       pclass  survived                                             name  \
# 1260       3         1                          Turja, Miss. Anna Sofia
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex   age  sibsp  parch  ticket     fare cabin embarked home.dest  \
# 1260  female  18.0      0      0    4138   9.8417   NaN        S       NaN
# 1261  female  63.0      0      0    4134   9.5875   NaN        S       NaN
# 1286  female  38.0      0      0    2688   7.2292   NaN        C       NaN
# 1290  female  47.0      1      0  363272   7.0000   NaN        S       NaN
# 1300  female  15.0      1      0    2659  14.4542   NaN        C       NaN
#
#       body boat
# 1260   NaN   15
# 1261   NaN   15
# 1286   NaN    C
# 1290   NaN  NaN
# 1300   NaN  NaN

# %% [markdown]
# And here we are filtering for those with more than 3 sibling/spouses (`sibsp`) on board or who paid more than £400 for their fare.

# %%
siblings_or_expensive = titanic[(titanic['sibsp'] > 3) | (titanic['fare'] > 400)]
siblings_or_expensive.head()
# Out:
#      pclass  survived                                               name  \
# 49        1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50        1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 183       1         1                             Lesurer, Mr. Gustave J
# 302       1         1                                   Ward, Miss. Anna
# 622       3         0            Andersson, Master. Sigvard Harald Elias
#
#         sex   age  sibsp  parch    ticket      fare        cabin embarked  \
# 49     male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 50   female  58.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 183    male  35.0      0      0  PC 17755  512.3292         B101        C
# 302  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 622    male   4.0      4      2    347082   31.2750          NaN        S
#
#                                           home.dest  body boat
# 49   Austria-Hungary / Germantown, Philadelphia, PA   NaN    3
# 50                     Germantown, Philadelphia, PA   NaN    3
# 183                                             NaN   NaN    3
# 302                                             NaN   NaN    3
# 622                             Sweden Winnipeg, MN   NaN  NaN

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise
#
# Filter the animals DataFrame where the IncidentNominalCost(£) Column was less than £400 **and** where the Borough column value is Croydon.

# %%
# Exercise

# %%
# %load ../solutions/chapter_4/animal_filter_one.py
# Filter the animals DataFrame:

# Filter the animals DataFrame where the IncidentNominalCost(£) Column was less than £400 *and* where the Borough coloumn value is Croydon.


cost_u400_croydon = animals[(animals['IncidentNominalCost(£)'] < 400) & (animals['Borough'] == "Croydon")]

cost_u400_croydon.head()
# Out:
#    IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 1          275091  01/01/2009 08:51     2009  2008/09  Special Service
# 8         4306091  07/01/2009 13:48     2009  2008/09  Special Service
# 15        5770091  09/01/2009 13:43     2009  2008/09  Special Service
# 19        6270091  10/01/2009 10:09     2009  2008/09  Special Service
# 44       14784091  25/01/2009 15:27     2009  2008/09  Special Service
#
#     PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 1         1.0             1.0                   255                   255.0
# 8         1.0             1.0                   255                   255.0
# 15        1.0             1.0                   255                   255.0
# 19        1.0             1.0                   255                   255.0
# 44        1.0             1.0                   255                   255.0
#
#                       FinalDescription                 AnimalGroupParent  \
# 1    ASSIST RSPCA WITH FOX TRAPPED,B15                               Fox
# 8   SQUIRREL TRAPPED ON WINDOWSILL,B15                          Squirrel
# 15               CAT STUCK UP TREE,B15                               Cat
# 19        INJURED DOG FOLLOWING RTA,B0                               Dog
# 44              ANIMAL IN DISTRESS,B15  Unknown - Domestic Animal Or Pet
#
#                                    PropertyType SpecialServiceTypeCategory  \
# 1                                      Railings    Other animal assistance
# 8                     House - single occupancy   Animal rescue from height
# 15                                  Tree scrub   Animal rescue from height
# 19                       Road surface/pavement     Other animal assistance
# 44  Domestic garden (vegetation not equipment)   Animal rescue from height
#
#                                    SpecialServiceType  Borough StnGroundName  \
# 1   Animal assistance involving livestock - Other ...  Croydon      Woodside
# 8                      Wild animal rescue from height  Croydon     Addington
# 15           Animal rescue from height - Domestic pet  Croydon      Woodside
# 19  Animal assistance involving livestock - Other ...  Croydon        Purley
# 44           Animal rescue from height - Domestic pet  Croydon      Woodside
#
#    AnimalClass  Code        London
# 1       Mammal  00AH  Outer London
# 8       Mammal  00AH  Outer London
# 15      Mammal  00AH  Outer London
# 19      Mammal  00AH  Outer London
# 44      Mammal  00AH  Outer London

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise
#
# Filter the animals DataFrame where the 'PropertyType' was "River/canal" **or** the `"PumpHoursTotal"` was greater than 8.

# %%
# Exercise

# %%
# %load ../solutions/chapter_4/animal_filter_two.py
# Filter the animals DataFrame:

# Filter the animals DataFrame where the 'PropertyType' was "River/canal" or the `"PumpHoursTotal"` was greater than 8.


river_pumphours = animals[(animals['PropertyType'] == "River/canal") | (animals['PumpHoursTotal'] > 8)]

river_pumphours
# Out:
#        IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 1289         49189111  06/04/2011 02:03     2011  2011/12  Special Service
# 1407         82423111  27/05/2011 06:50     2011  2011/12  Special Service
# 1477        101755111  29/06/2011 21:04     2011  2011/12  Special Service
# 2542         48360131  19/04/2013 07:01     2013  2013/14  Special Service
# 3143         49076141  22/04/2014 09:54     2014  2014/15  Special Service
# 3757         62700151  22/05/2015 11:34     2015  2015/16  Special Service
# 4450  098141-28072016  28/07/2016 13:49     2016  2016/17  Special Service
#
#       PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 1289        3.0             9.0                   260                  2340.0
# 1407        3.0             9.0                   260                  2340.0
# 1477        3.0             9.0                   260                  2340.0
# 2542        2.0            12.0                   290                  3480.0
# 3143        2.0             9.0                   295                  2655.0
# 3757        2.0            10.0                   298                  2980.0
# 4450        3.0            12.0                   326                  3912.0
#
#                                        FinalDescription AnimalGroupParent  \
# 1289  HORSE IN RIVER IMPLEMENT WATER RESCUE PROCEDUR...             Horse
# 1407  HORSE  TRAPPED IN WATER CHANNEL LINE OPS 2 WAT...             Horse
# 1477               DEER IN CANAL - WATER RESCUE LEVEL 2              Deer
# 2542          FOAL IN RIVER WATER LEVEL ONE IMPLEMENTED             Horse
# 3143                          KITTEN TRAPPED IN CHIMNEY               Cat
# 3757                   HORSE FALLEN INTO SWIMMING  POOL             Horse
# 4450   CAT STUCK WITHIN WALL SPACE  RSPCA IN ATTENDANCE               Cat
#
#                                            PropertyType  \
# 1289                                       River/canal
# 1407                                       River/canal
# 1477                                       River/canal
# 2542                                       River/canal
# 3143  Purpose Built Flats/Maisonettes - Up to 3 stor...
# 3757                          Other outdoor structures
# 4450  Purpose Built Flats/Maisonettes - 4 to 9 storeys
#
#      SpecialServiceTypeCategory  \
# 1289   Animal rescue from water
# 1407   Animal rescue from water
# 1477   Animal rescue from water
# 2542    Other animal assistance
# 3143    Other animal assistance
# 3757   Animal rescue from water
# 4450    Other animal assistance
#
#                                      SpecialServiceType         Borough  \
# 1289             Animal rescue from water - Farm animal  Waltham Forest
# 1407             Animal rescue from water - Farm animal  Waltham Forest
# 1477               Wild animal rescue from water or mud   Tower Hamlets
# 2542    Animal assistance - Lift heavy livestock animal  Waltham Forest
# 3143                     Assist trapped domestic animal        Hounslow
# 3757             Animal rescue from water - Farm animal         Bromley
# 4450  Animal assistance involving domestic animal - ...          Camden
#
#      StnGroundName AnimalClass  Code        London
# 1289   Walthamstow      Mammal  00BH  Outer London
# 1407   Walthamstow      Mammal  00BH  Outer London
# 1477        Poplar      Mammal  00BG  Inner London
# 2542     Chingford      Mammal  00BH  Outer London
# 3143       Feltham      Mammal  00AT  Outer London
# 3757   Biggin Hill      Mammal  00AF  Outer London
# 4450  Kentish Town      Mammal  00AG  Inner London

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ## Some Filter short cuts.
#
# We can also use some other filters to make life easier.
#
# with `.isin()` we can provide a list of things to filter – here the boat identities `[“2”, “C”, “15”]`

# %%
titanic[titanic["boat"].isin(["2", "C", "15"])].head()
# Out:
#      pclass  survived                                               name  \
# 56        1         1                         Carter, Mr. William Ernest
# 79        1         1  Cornell, Mrs. Robert Clifford (Malvina Helen L...
# 98        1         1        Douglas, Mrs. Walter Donald (Mahala Dutton)
# 164       1         1                    Homer, Mr. Harry ("Mr E Haven")
# 170       1         1                            Ismay, Mr. Joseph Bruce
#
#         sex   age  sibsp  parch    ticket     fare        cabin embarked  \
# 56     male  36.0      1      2    113760  120.000      B96 B98        S
# 79   female  55.0      2      0     11770   25.700         C101        S
# 98   female  48.0      1      0  PC 17761  106.425          C86        C
# 164    male  35.0      0      0    111426   26.550          NaN        C
# 170    male  49.0      0      0    112058    0.000  B52 B54 B56        S
#
#                             home.dest  body boat
# 56                      Bryn Mawr, PA   NaN    C
# 79                       New York, NY   NaN    2
# 98   Deephaven, MN / Cedar Rapids, IA   NaN    2
# 164                  Indianapolis, IN   NaN   15
# 170                         Liverpool   NaN    C

# %% [markdown]
# If dealing with numeric values we can use `.between()` and specify an upper and lower bound.
#
# Here we’re looking where the `age` column was between 0 and 12.

# %%
titanic[titanic["age"].between(30, 40)]
# Out:
#       pclass  survived                                               name  \
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 7          1         0                             Andrews, Mr. Thomas Jr
# 18         1         1                              Bazzani, Miss. Albina
# 19         1         0                               Beattie, Mr. Thomson
# 20         1         1                      Beckwith, Mr. Richard Leonard
# 28         1         1                             Bissette, Miss. Amelia
# 31         1         1                                   Blank, Mr. Henry
# 32         1         1                            Bonnell, Miss. Caroline
# 49         1         1                 Cardeza, Mr. Thomas Drake Martinez
# 51         1         0                           Carlsson, Mr. Frans Olof
# 56         1         1                         Carter, Mr. William Ernest
# 57         1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 60         1         0                      Cavendish, Mr. Tyrell William
# 65         1         1     Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 66         1         1                        Chaudanson, Miss. Victorine
# 67         1         1                               Cherry, Miss. Gladys
# 76         1         1                        Compton, Miss. Sara Rebecca
# 77         1         0                   Compton, Mr. Alexander Taylor Jr
# 82         1         1                            Crosby, Miss. Harriet R
# 84         1         0                          Cumings, Mr. John Bradley
# 85         1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 88         1         1                               Daniels, Miss. Sarah
# 89         1         0                             Davidson, Mr. Thornton
# 91         1         1                            Dick, Mr. Albert Adrian
# 101        1         0                       Dulles, Mr. William Crothers
# 103        1         1                      Endres, Miss. Caroline Louise
# 105        1         0                           Evans, Miss. Edith Corse
# 109        1         1                   Flynn, Mr. John Irwin ("Irving")
# 110        1         0                    Foreman, Mr. Benjamin Laventall
# 117        1         1                     Francatelli, Miss. Laura Mabel
# ...      ...       ...                                                ...
# 1051       3         0                       Nancarrow, Mr. William Henry
# 1064       3         1                                 Niskanen, Mr. Juha
# 1086       3         0                                Olsson, Miss. Elina
# 1088       3         1                          Olsson, Mr. Oscar Wilhelm
# 1094       3         1                                   Osman, Mrs. Mara
# 1110       3         0                                Pavlovic, Mr. Stefo
# 1131       3         1                 Pickard, Mr. Berk (Berk Trembisky)
# 1139       3         0                                    Rekic, Mr. Tido
# 1146       3         0               Rice, Mrs. William (Margaret Norton)
# 1148       3         0                               Rintamaki, Mr. Matti
# 1169       3         0                       Saether, Mr. Simon Sivertsen
# 1183       3         0                          Salonen, Mr. Johan Werner
# 1203       3         0                                  Sivic, Mr. Husein
# 1210       3         0                                 Skoog, Mr. Wilhelm
# 1218       3         0                      Somerton, Mr. Francis William
# 1220       3         0                            Spinner, Mr. Henry John
# 1222       3         0                                Stankovic, Mr. Ivan
# 1228       3         1                                 Stranden, Mr. Juho
# 1239       3         0                       Theobald, Mr. Thomas Leonard
# 1248       3         0                                 Tikkanen, Mr. Juho
# 1251       3         0                         Tomlin, Mr. Ernest Portage
# 1259       3         0                                Turcin, Mr. Stjepan
# 1266       3         0                        Van Impe, Mr. Jean Baptiste
# 1267       3         0  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 1269       3         0                   Vande Velde, Mr. Johannes Joseph
# 1274       3         0                          Vander Planke, Mr. Julius
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1285       3         0                                Wenzel, Mr. Linhart
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1298       3         0                          Wittevrongel, Mr. Camille
#
#          sex   age  sibsp  parch              ticket      fare        cabin  \
# 3       male  30.0      1      2              113781  151.5500      C22 C26
# 7       male  39.0      0      0              112050    0.0000          A36
# 18    female  32.0      0      0               11813   76.2917          D15
# 19      male  36.0      0      0               13050   75.2417           C6
# 20      male  37.0      1      1               11751   52.5542          D35
# 28    female  35.0      0      0            PC 17760  135.6333          C99
# 31      male  40.0      0      0              112277   31.0000          A31
# 32    female  30.0      0      0               36928  164.8667           C7
# 49      male  36.0      0      1            PC 17755  512.3292  B51 B53 B55
# 51      male  33.0      0      0                 695    5.0000  B51 B53 B55
# 56      male  36.0      1      2              113760  120.0000      B96 B98
# 57    female  36.0      1      2              113760  120.0000      B96 B98
# 60      male  36.0      1      0               19877   78.8500          C46
# 65    female  33.0      1      0              113806   53.1000           E8
# 66    female  36.0      0      0            PC 17608  262.3750          B61
# 67    female  30.0      0      0              110152   86.5000          B77
# 76    female  39.0      1      1            PC 17756   83.1583          E49
# 77      male  37.0      1      1            PC 17756   83.1583          E52
# 82    female  36.0      0      2           WE/P 5735   71.0000          B22
# 84      male  39.0      1      0            PC 17599   71.2833          C85
# 85    female  38.0      1      0            PC 17599   71.2833          C85
# 88    female  33.0      0      0              113781  151.5500          NaN
# 89      male  31.0      1      0          F.C. 12750   52.0000          B71
# 91      male  31.0      1      0               17474   57.0000          B20
# 101     male  39.0      0      0            PC 17580   29.7000          A18
# 103   female  38.0      0      0            PC 17757  227.5250          C45
# 105   female  36.0      0      0            PC 17531   31.6792          A29
# 109     male  36.0      0      0            PC 17474   26.3875          E25
# 110     male  30.0      0      0              113051   27.7500         C111
# 117   female  30.0      0      0            PC 17485   56.9292          E36
# ...      ...   ...    ...    ...                 ...       ...          ...
# 1051    male  33.0      0      0          A./5. 3338    8.0500          NaN
# 1064    male  39.0      0      0   STON/O 2. 3101289    7.9250          NaN
# 1086  female  31.0      0      0              350407    7.8542          NaN
# 1088    male  32.0      0      0              347079    7.7750          NaN
# 1094  female  31.0      0      0              349244    8.6833          NaN
# 1110    male  32.0      0      0              349242    7.8958          NaN
# 1131    male  32.0      0      0   SOTON/O.Q. 392078    8.0500          E10
# 1139    male  38.0      0      0              349249    7.8958          NaN
# 1146  female  39.0      0      5              382652   29.1250          NaN
# 1148    male  35.0      0      0   STON/O 2. 3101273    7.1250          NaN
# 1169    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500          NaN
# 1183    male  39.0      0      0             3101296    7.9250          NaN
# 1203    male  40.0      0      0              349251    7.8958          NaN
# 1210    male  40.0      1      4              347088   27.9000          NaN
# 1218    male  30.0      0      0          A.5. 18509    8.0500          NaN
# 1220    male  32.0      0      0     STON/OQ. 369943    8.0500          NaN
# 1222    male  33.0      0      0              349239    8.6625          NaN
# 1228    male  31.0      0      0   STON/O 2. 3101288    7.9250          NaN
# 1239    male  34.0      0      0              363294    8.0500          NaN
# 1248    male  32.0      0      0   STON/O 2. 3101293    7.9250          NaN
# 1251    male  30.5      0      0              364499    8.0500          NaN
# 1259    male  36.0      0      0              349247    7.8958          NaN
# 1266    male  36.0      1      1              345773   24.1500          NaN
# 1267  female  30.0      1      1              345773   24.1500          NaN
# 1269    male  33.0      0      0              345780    9.5000          NaN
# 1274    male  31.0      3      0              345763   18.0000          NaN
# 1276  female  31.0      1      0              345763   18.0000          NaN
# 1285    male  32.5      0      0              345775    9.5000          NaN
# 1286  female  38.0      0      0                2688    7.2292          NaN
# 1298    male  36.0      0      0              345771    9.5000          NaN
#
#      embarked                                       home.dest   body boat
# 3           S                 Montreal, PQ / Chesterville, ON  135.0  NaN
# 7           S                                     Belfast, NI    NaN  NaN
# 18          C                                             NaN    NaN    8
# 19          C                                    Winnipeg, MN    NaN    A
# 20          S                                    New York, NY    NaN    5
# 28          S                                             NaN    NaN    8
# 31          C                                  Glen Ridge, NJ    NaN    7
# 32          S                                  Youngstown, OH    NaN    8
# 49          C  Austria-Hungary / Germantown, Philadelphia, PA    NaN    3
# 51          S                                    New York, NY    NaN  NaN
# 56          S                                   Bryn Mawr, PA    NaN    C
# 57          S                                   Bryn Mawr, PA    NaN    4
# 60          S                         Little Onn Hall, Staffs  172.0  NaN
# 65          S                       New York, NY / Ithaca, NY    NaN    5
# 66          C                                             NaN    NaN    4
# 67          S                                 London, England    NaN    8
# 76          C                                    Lakewood, NJ    NaN   14
# 77          C                                    Lakewood, NJ    NaN  NaN
# 82          S                                   Milwaukee, WI    NaN    7
# 84          C                                    New York, NY    NaN  NaN
# 85          C                                    New York, NY    NaN    4
# 88          S                                             NaN    NaN    8
# 89          S                                    Montreal, PQ    NaN  NaN
# 91          S                                     Calgary, AB    NaN    3
# 101         C                                Philadelphia, PA  133.0  NaN
# 103         C                                    New York, NY    NaN    4
# 105         C                                    New York, NY    NaN  NaN
# 109         S                                    Brooklyn, NY    NaN    5
# 110         C                                    New York, NY    NaN  NaN
# 117         C                                             NaN    NaN    1
# ...       ...                                             ...    ...  ...
# 1051        S                                             NaN    NaN  NaN
# 1064        S                                             NaN    NaN    9
# 1086        S                                             NaN    NaN  NaN
# 1088        S                                             NaN    NaN    A
# 1094        S                                             NaN    NaN  NaN
# 1110        S                                             NaN    NaN  NaN
# 1131        S                                             NaN    NaN    9
# 1139        S                                             NaN    NaN  NaN
# 1146        Q                                             NaN  327.0  NaN
# 1148        S                                             NaN    NaN  NaN
# 1169        S                                             NaN   32.0  NaN
# 1183        S                                             NaN    NaN  NaN
# 1203        S                                             NaN    NaN  NaN
# 1210        S                                             NaN    NaN  NaN
# 1218        S                                             NaN    NaN  NaN
# 1220        S                                             NaN    NaN  NaN
# 1222        C                                             NaN    NaN  NaN
# 1228        S                                             NaN    NaN    9
# 1239        S                                             NaN  176.0  NaN
# 1248        S                                             NaN    NaN  NaN
# 1251        S                                             NaN   50.0  NaN
# 1259        S                                             NaN    NaN  NaN
# 1266        S                                             NaN    NaN  NaN
# 1267        S                                             NaN    NaN  NaN
# 1269        S                                             NaN    NaN  NaN
# 1274        S                                             NaN    NaN  NaN
# 1276        S                                             NaN    NaN  NaN
# 1285        S                                             NaN  298.0  NaN
# 1286        C                                             NaN    NaN    C
# 1298        S                                             NaN    NaN  NaN
#
# [250 rows x 14 columns]

# %% [markdown]
# We also have the `~` tilde symbol to invert an expression, this works similarly to the `!=` for does not equal.
#
# For example, I can invert the filter for female passengers to return just male passengers.
#
# Note – I have to wrap my conditional statement in round brackets to ensure this works.

# %%
titanic[~(titanic["embarked"] == "S")]  # Inverts the results of == Female; effectively giving == Male
# Out:
#       pclass  survived                                               name  \
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 16         1         0                           Baxter, Mr. Quigg Edmond
# 17         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18         1         1                              Bazzani, Miss. Albina
# 19         1         0                               Beattie, Mr. Thomson
# 22         1         1                              Behr, Mr. Karl Howell
# 23         1         1                              Bidois, Miss. Rosalie
# 25         1         0                                Birnbaum, Mr. Jakob
# 26         1         1                            Bishop, Mr. Dickinson H
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 31         1         1                                   Blank, Mr. Henry
# 35         1         1                           Bowen, Miss. Grace Scott
# 39         1         0                                 Brandeis, Mr. Emil
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 41         1         1          Brown, Mrs. James Joseph (Margaret Tobin)
# 43         1         1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 44         1         1                    Burns, Miss. Elizabeth Margaret
# 48         1         1   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 49         1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50         1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 66         1         1                        Chaudanson, Miss. Victorine
# 68         1         1                           Chevre, Mr. Paul Romaine
# 71         1         0                           Clark, Mr. Walter Miller
# 72         1         1      Clark, Mrs. Walter Miller (Virginia McDowell)
# 76         1         1                        Compton, Miss. Sara Rebecca
# 77         1         0                   Compton, Mr. Alexander Taylor Jr
# ...      ...       ...                                                ...
# 1186       3         0                                Samaan, Mr. Youssef
# 1193       3         0                                 Scanlan, Mr. James
# 1195       3         0                           Shaughnessy, Mr. Patrick
# 1198       3         1                         Shine, Miss. Ellen Natalia
# 1201       3         0                              Sirayanian, Mr. Orsen
# 1215       3         0                                  Smith, Mr. Thomas
# 1216       3         1                                 Smyth, Miss. Julia
# 1222       3         0                                Stankovic, Mr. Ivan
# 1240       3         1                    Thomas, Master. Assad Alexander
# 1241       3         0                              Thomas, Mr. Charles P
# 1242       3         0                                   Thomas, Mr. John
# 1243       3         0                                Thomas, Mr. Tannous
# 1244       3         1          Thomas, Mrs. Alexander (Thamine "Thelma")
# 1249       3         0                                   Tobin, Mr. Roger
# 1253       3         0                                   Torfa, Mr. Assad
# 1255       3         0                                  Toufik, Mr. Nakli
# 1256       3         1                     Touma, Master. Georges Youssef
# 1257       3         1                         Touma, Miss. Maria Youssef
# 1258       3         1            Touma, Mrs. Darwis (Hanne Youssef Razi)
# 1277       3         1                               Vartanian, Mr. David
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1299       3         0                                Yasbeck, Mr. Antoni
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1301       3         0                               Youseff, Mr. Gerious
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
# 1306       3         0                          Zakarian, Mr. Mapriededer
# 1307       3         0                                Zakarian, Mr. Ortin
#
#          sex      age  sibsp  parch    ticket      fare        cabin embarked  \
# 9       male  71.0000      0      0  PC 17609   49.5042          NaN        C
# 10      male  47.0000      1      0  PC 17757  227.5250      C62 C64        C
# 11    female  18.0000      1      0  PC 17757  227.5250      C62 C64        C
# 12    female  24.0000      0      0  PC 17477   69.3000          B35        C
# 16      male  24.0000      0      1  PC 17558  247.5208      B58 B60        C
# 17    female  50.0000      0      1  PC 17558  247.5208      B58 B60        C
# 18    female  32.0000      0      0     11813   76.2917          D15        C
# 19      male  36.0000      0      0     13050   75.2417           C6        C
# 22      male  26.0000      0      0    111369   30.0000         C148        C
# 23    female  42.0000      0      0  PC 17757  227.5250          NaN        C
# 25      male  25.0000      0      0     13905   26.0000          NaN        C
# 26      male  25.0000      1      0     11967   91.0792          B49        C
# 27    female  19.0000      1      0     11967   91.0792          B49        C
# 31      male  40.0000      0      0    112277   31.0000          A31        C
# 35    female  45.0000      0      0  PC 17608  262.3750          NaN        C
# 39      male  48.0000      0      0  PC 17591   50.4958          B10        C
# 40      male      NaN      0      0    112379   39.6000          NaN        C
# 41    female  44.0000      0      0  PC 17610   27.7208           B4        C
# 43    female  60.0000      0      0     11813   76.2917          D15        C
# 44    female  41.0000      0      0     16966  134.5000          E40        C
# 48    female  53.0000      0      0  PC 17606   27.4458          NaN        C
# 49      male  36.0000      0      1  PC 17755  512.3292  B51 B53 B55        C
# 50    female  58.0000      0      1  PC 17755  512.3292  B51 B53 B55        C
# 59    female      NaN      0      0     17770   27.7208          NaN        C
# 66    female  36.0000      0      0  PC 17608  262.3750          B61        C
# 68      male  45.0000      0      0  PC 17594   29.7000           A9        C
# 71      male  27.0000      1      0     13508  136.7792          C89        C
# 72    female  26.0000      1      0     13508  136.7792          C89        C
# 76    female  39.0000      1      1  PC 17756   83.1583          E49        C
# 77      male  37.0000      1      1  PC 17756   83.1583          E52        C
# ...      ...      ...    ...    ...       ...       ...          ...      ...
# 1186    male      NaN      2      0      2662   21.6792          NaN        C
# 1193    male      NaN      0      0     36209    7.7250          NaN        Q
# 1195    male      NaN      0      0    370374    7.7500          NaN        Q
# 1198  female      NaN      0      0    330968    7.7792          NaN        Q
# 1201    male  22.0000      0      0      2669    7.2292          NaN        C
# 1215    male      NaN      0      0    384461    7.7500          NaN        Q
# 1216  female      NaN      0      0    335432    7.7333          NaN        Q
# 1222    male  33.0000      0      0    349239    8.6625          NaN        C
# 1240    male   0.4167      0      1      2625    8.5167          NaN        C
# 1241    male      NaN      1      0      2621    6.4375          NaN        C
# 1242    male      NaN      0      0      2681    6.4375          NaN        C
# 1243    male      NaN      0      0      2684    7.2250          NaN        C
# 1244  female  16.0000      1      1      2625    8.5167          NaN        C
# 1249    male      NaN      0      0    383121    7.7500          F38        Q
# 1253    male      NaN      0      0      2673    7.2292          NaN        C
# 1255    male      NaN      0      0      2641    7.2292          NaN        C
# 1256    male   7.0000      1      1      2650   15.2458          NaN        C
# 1257  female   9.0000      1      1      2650   15.2458          NaN        C
# 1258  female  29.0000      0      2      2650   15.2458          NaN        C
# 1277    male  22.0000      0      0      2658    7.2250          NaN        C
# 1286  female  38.0000      0      0      2688    7.2292          NaN        C
# 1299    male  27.0000      1      0      2659   14.4542          NaN        C
# 1300  female  15.0000      1      0      2659   14.4542          NaN        C
# 1301    male  45.5000      0      0      2628    7.2250          NaN        C
# 1302    male      NaN      0      0      2647    7.2250          NaN        C
# 1303    male      NaN      0      0      2627   14.4583          NaN        C
# 1304  female  14.5000      1      0      2665   14.4542          NaN        C
# 1305  female      NaN      1      0      2665   14.4542          NaN        C
# 1306    male  26.5000      0      0      2656    7.2250          NaN        C
# 1307    male  27.0000      0      0      2670    7.2250          NaN        C
#
#                                            home.dest   body   boat
# 9                                Montevideo, Uruguay   22.0    NaN
# 10                                      New York, NY  124.0    NaN
# 11                                      New York, NY    NaN      4
# 12                                     Paris, France    NaN      9
# 16                                      Montreal, PQ    NaN    NaN
# 17                                      Montreal, PQ    NaN      6
# 18                                               NaN    NaN      8
# 19                                      Winnipeg, MN    NaN      A
# 22                                      New York, NY    NaN      5
# 23                                               NaN    NaN      4
# 25                                 San Francisco, CA  148.0    NaN
# 26                                      Dowagiac, MI    NaN      7
# 27                                      Dowagiac, MI    NaN      7
# 31                                    Glen Ridge, NJ    NaN      7
# 35                                   Cooperstown, NY    NaN      4
# 39                                         Omaha, NE  208.0    NaN
# 40                                  Philadelphia, PA    NaN    NaN
# 41                                        Denver, CO    NaN      6
# 43                                  Philadelphia, PA    NaN      8
# 44                                               NaN    NaN      3
# 48                                    Washington, DC    NaN      6
# 49    Austria-Hungary / Germantown, Philadelphia, PA    NaN      3
# 50                      Germantown, Philadelphia, PA    NaN      3
# 59                                      New York, NY    NaN      5
# 66                                               NaN    NaN      4
# 68                                     Paris, France    NaN      7
# 71                                   Los Angeles, CA    NaN    NaN
# 72                                   Los Angeles, CA    NaN      4
# 76                                      Lakewood, NJ    NaN     14
# 77                                      Lakewood, NJ    NaN    NaN
# ...                                              ...    ...    ...
# 1186                                             NaN    NaN    NaN
# 1193                                             NaN    NaN    NaN
# 1195                                             NaN    NaN    NaN
# 1198                                             NaN    NaN    NaN
# 1201                                             NaN    NaN    NaN
# 1215                                             NaN    NaN    NaN
# 1216                                             NaN    NaN     13
# 1222                                             NaN    NaN    NaN
# 1240                                             NaN    NaN     16
# 1241                                             NaN    NaN    NaN
# 1242                                             NaN    NaN    NaN
# 1243                                             NaN    NaN    NaN
# 1244                                             NaN    NaN     14
# 1249                                             NaN    NaN    NaN
# 1253                                             NaN    NaN    NaN
# 1255                                             NaN    NaN    NaN
# 1256                                             NaN    NaN      C
# 1257                                             NaN    NaN      C
# 1258                                             NaN    NaN      C
# 1277                                             NaN    NaN  13 15
# 1286                                             NaN    NaN      C
# 1299                                             NaN    NaN      C
# 1300                                             NaN    NaN    NaN
# 1301                                             NaN  312.0    NaN
# 1302                                             NaN    NaN    NaN
# 1303                                             NaN    NaN    NaN
# 1304                                             NaN  328.0    NaN
# 1305                                             NaN    NaN    NaN
# 1306                                             NaN  304.0    NaN
# 1307                                             NaN    NaN    NaN
#
# [395 rows x 14 columns]

# %% [markdown]
# The tilde `~` can be useful for other scenarios, there’s a variety of `.is` methods for example that do not have an is not equivalent; but we can invert the `.is` method instead. We’ll see an example of that in chapter 5.

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ## Filtering Text
#
# So far when we've talked about filtering text we do so on exact matches.
#
# As Python is case sensitive filtering for `“cat”` will not show the values `“CAT”` or `“Cat”` or `cAt` in our `cat_dog` DataFrame.

# %%
# Lets create our cat_dog DataFrame again with some variation in the capitalisation of "cat"

cat_dog_wrong_spelling = pd.DataFrame({"animal": ["cat", "Cat", "Dog", "cat", "Dog", "Rat", "Bat"] , 
                                       "name": ["Catalie Portman","Pico de Gato", "Chewbarka", "JK Meowling", "K9", "Roland", "Vlad"],
                                       "age": [3, 5, 1, 7, 11, 1, 3]} , 
                                      columns = ["name", "animal", "age"])

cat_dog_wrong_spelling
# Out:
#               name animal  age
# 0  Catalie Portman    cat    3
# 1     Pico de Gato    Cat    5
# 2        Chewbarka    Dog    1
# 3      JK Meowling    cat    7
# 4               K9    Dog   11
# 5           Roland    Rat    1
# 6             Vlad    Bat    3

# %% [markdown]
# Here the filter condition we previously used (`== Cat`) will only now only return us `Pico De Gato`

# %%
cat_only_spelling = cat_dog_wrong_spelling[cat_dog_wrong_spelling["animal"] == "Cat"]
cat_only_spelling
# Out:
#            name animal  age
# 1  Pico de Gato    Cat    5

# %% [markdown]
# Which is not the result we wanted - due to Python's case sensitivity.
#
# For simple instances we can use the string method `str.contains()` like in the example below.
#
# Here in our DataFrame some entries in the `"Animal"` column have "Cat" and others have "cat".
#
# By using `.str.contains(“at”)` - we can bring in both values because both contain the partial string "at".

# %%
# Filter to find instances where the string in "animal" contains "at"
cat_only_spelling = cat_dog_wrong_spelling[cat_dog_wrong_spelling["animal"].str.contains("at")]
cat_only_spelling
# Out:
#               name animal  age
# 0  Catalie Portman    cat    3
# 1     Pico de Gato    Cat    5
# 3      JK Meowling    cat    7
# 5           Roland    Rat    1
# 6             Vlad    Bat    3

# %% [markdown]
# This obviously is not foolproof as both `Rat` and `Bat` also have `at` in them!
#
# In chapter 5 we'll look at changing the column values to lowercase - which would allow a straight forward filter to work in this case.
#
# For more complex cases we can use what is known as Regular Expresions or RegEx in Python to search for partial strings.
#
# We do not cover these in this introduction course; but here are some more resources you may wish to explore. If you have used Regular Expressions in other languages you will find this very familiar.
#
# [ RegEx How to]( https://docs.python.org/3/howto/regex.html)
#
# [Python Regular Expressions]( https://developers.google.com/edu/python/regular-expressions)
#
# [Datacamp RegEx tutorial]( https://www.datacamp.com/community/tutorials/python-regular-expression-tutorial)

# %% [markdown]
# We’ve looked here at the base Python way of filtering, as with many things in Python there are other alternatives. Some include:

# %%
titanic.query('fare > 50 & sex == "male"').head()
# Out:
#     pclass  survived                                  name   sex      age  \
# 1        1         1        Allison, Master. Hudson Trevor  male   0.9167
# 3        1         0  Allison, Mr. Hudson Joshua Creighton  male  30.0000
# 10       1         0                Astor, Col. John Jacob  male  47.0000
# 16       1         0              Baxter, Mr. Quigg Edmond  male  24.0000
# 19       1         0                  Beattie, Mr. Thomson  male  36.0000
#
#     sibsp  parch    ticket      fare    cabin embarked  \
# 1       1      2    113781  151.5500  C22 C26        S
# 3       1      2    113781  151.5500  C22 C26        S
# 10      1      0  PC 17757  227.5250  C62 C64        C
# 16      0      1  PC 17558  247.5208  B58 B60        C
# 19      0      0     13050   75.2417       C6        C
#
#                           home.dest   body boat
# 1   Montreal, PQ / Chesterville, ON    NaN   11
# 3   Montreal, PQ / Chesterville, ON  135.0  NaN
# 10                     New York, NY  124.0  NaN
# 16                     Montreal, PQ    NaN  NaN
# 19                     Winnipeg, MN    NaN    A

# %% [markdown]
# `.filter()` works on the *index* - not the contents!
#
# Here I’m looking for `like = “1”` which will give me index `1` , `11` , `12` as they contain the number 1.
#
# So far we’ve worked with indexes that are numerical – from 0 to n; but they can also be text based; and using the pandas `.filter()` would be useful here.

# %%
titanic.filter(like = "1", axis = 0).head()
# Out:
#     pclass  survived                                               name  \
# 1        1         1                     Allison, Master. Hudson Trevor
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
#
#        sex      age  sibsp  parch    ticket     fare    cabin embarked  \
# 1     male   0.9167      1      2    113781  151.550  C22 C26        S
# 10    male  47.0000      1      0  PC 17757  227.525  C62 C64        C
# 11  female  18.0000      1      0  PC 17757  227.525  C62 C64        C
# 12  female  24.0000      0      0  PC 17477   69.300      B35        C
# 13  female  26.0000      0      0     19877   78.850      NaN        S
#
#                           home.dest   body boat
# 1   Montreal, PQ / Chesterville, ON    NaN   11
# 10                     New York, NY  124.0  NaN
# 11                     New York, NY    NaN    4
# 12                    Paris, France    NaN    9
# 13                              NaN    NaN    6

# %% [markdown]
# You many find even more ways of filtering your data – there’s lots out there!

# %% [markdown]
# [return to menu](#menu)

# %% [markdown]
# <a id='new_columns'></a>
# <hr style="width:100%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:1">

# %% [markdown]
# ## Deriving New Columns

# %% [markdown]
# We create new columns in very similar ways:
#
# <center> `titanic["new_column"] = 1` </center>
#
#
# In the example above we are creating a new column in the `titanic` DataFrame called `"new_column"`, which will have the constant value of 1 in each row.
#
# * To create a new column we first give the DataFrame name and use square brackets to specify, as a string our column name – here `"new_column"`
#     * If the column name does not exist in our Dataframe (like in the example) the contents will be placed in a new column, at the end of the DataFrame.
#     * If the column already exists in our DataFrame the contents of that column will be **overwritten**.
#
#
# * We then use the assignment operator "` = `"
#
#
# * After the assignment operator is what we fill our column with – here a constant value of the integer 1.
#
# We’ll now look at various different ways we can fill these new columns.

# %% [markdown]
# ### Constant Values

# %% [markdown]
# Constant values are values that are the same all the way through the column.
#
# These are created by placing the value after the `=` assignment operator.
#
# Some examples are in the cell below.

# %%
# Let's remind ourselves what cat_dog looks like

cat_dog.head()
# Out:
#               name animal  age
# 0  Catalie Portman    Cat    3
# 1     Pico de Gato    Cat    5
# 2        Chewbarka    Dog    1
# 3      JK Meowling    Cat    7
# 4               K9    Dog   11

# %%
# Let's add new columns

cat_dog["constant_string"] = "mammal"   # adds a string/object constant
cat_dog["constant_float"] = 3.2 # adds a floating point constant
cat_dog["constant_int"] = 8   # adds an interger constant

cat_dog

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise
#
# Add a new constant value to the `animals` dataframe.
#
# Call your new column `attended` and set the value to be `True`.

# %%
# Exercise
type("True"), type(True)
# Out:
# (str, bool)

# %%
# %load ../solutions/chapter_4/constantvalue.py
# Add a new constant value to the animals DataFrame

# Call the new column "attended"
# Set the value to True

animals['attended'] = True

# View the dataframe

animals.head()
# Out:
#   IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0         139091  01/01/2009 03:01     2009  2008/09  Special Service
# 1         275091  01/01/2009 08:51     2009  2008/09  Special Service
# 2        2075091  04/01/2009 10:07     2009  2008/09  Special Service
# 3        2872091  05/01/2009 12:27     2009  2008/09  Special Service
# 4        3553091  06/01/2009 15:23     2009  2008/09  Special Service
#
#    PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 0        1.0             2.0                   255                   510.0
# 1        1.0             1.0                   255                   255.0
# 2        1.0             1.0                   255                   255.0
# 3        1.0             1.0                   255                   255.0
# 4        1.0             1.0                   255                   255.0
#
#                             FinalDescription AnimalGroupParent  \
# 0  DOG WITH JAW TRAPPED IN MAGAZINE RACK,B15               Dog
# 1          ASSIST RSPCA WITH FOX TRAPPED,B15               Fox
# 2                    DOG CAUGHT IN DRAIN,B15               Dog
# 3                  HORSE TRAPPED IN LAKE,J17             Horse
# 4              RABBIT TRAPPED UNDER SOFA,B15            Rabbit
#
#                                     PropertyType  \
# 0                      House - single occupancy
# 1                                       Railings
# 2                                 Pipe or drain
# 3  Intensive Farming Sheds (chickens, pigs etc)
# 4                      House - single occupancy
#
#         SpecialServiceTypeCategory  \
# 0          Other animal assistance
# 1          Other animal assistance
# 2  Animal rescue from below ground
# 3         Animal rescue from water
# 4          Other animal assistance
#
#                                   SpecialServiceType     Borough  \
# 0  Animal assistance involving livestock - Other ...     Croydon
# 1  Animal assistance involving livestock - Other ...     Croydon
# 2     Animal rescue from below ground - Domestic pet      Sutton
# 3             Animal rescue from water - Farm animal  Hillingdon
# 4  Animal assistance involving livestock - Other ...    Havering
#
#   StnGroundName AnimalClass  Code        London  attended
# 0       Norbury      Mammal  00AH  Outer London      True
# 1      Woodside      Mammal  00AH  Outer London      True
# 2    Wallington      Mammal  00BF  Outer London      True
# 3       Ruislip      Mammal  00AS  Outer London      True
# 4   Harold Hill      Mammal  00AR  Outer London      True

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Numeric Values

# %% [markdown]
# We can add in numeric columns too.
#
# We can do any form of operations we like here – for example creating the family size of the person.
#
# This is the number of siblings or spouses on board (`sibsp`), the number of parents or children on board (`parch`), plus 1 (the person themselves).

# %%
titanic["family_size"] = titanic["sibsp"] + titanic["parch"] + 1

titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000      0      0   24160  211.3375       B5        S
# 1   0.9167      1      2  113781  151.5500  C22 C26        S
# 2   2.0000      1      2  113781  151.5500  C22 C26        S
# 3  30.0000      1      2  113781  151.5500  C22 C26        S
# 4  25.0000      1      2  113781  151.5500  C22 C26        S
#
#                          home.dest   body boat  family_size
# 0                     St Louis, MO    NaN    2            1
# 1  Montreal, PQ / Chesterville, ON    NaN   11            4
# 2  Montreal, PQ / Chesterville, ON    NaN  NaN            4
# 3  Montreal, PQ / Chesterville, ON  135.0  NaN            4
# 4  Montreal, PQ / Chesterville, ON    NaN  NaN            4

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Boolean and Binary Values

# %% [markdown]
# Using the same conditions as we do when filtering we can also create Boolean (True/False) columns.
#
#
# In the example below I am assigning `True` to all values in the `age` column that are under 18. My new column is called `"under_18_bool"`

# %%
titanic["under_18_bool"] = titanic["age"] < 18
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000      0      0   24160  211.3375       B5        S
# 1   0.9167      1      2  113781  151.5500  C22 C26        S
# 2   2.0000      1      2  113781  151.5500  C22 C26        S
# 3  30.0000      1      2  113781  151.5500  C22 C26        S
# 4  25.0000      1      2  113781  151.5500  C22 C26        S
#
#                          home.dest   body boat  family_size  under_18_bool
# 0                     St Louis, MO    NaN    2            1          False
# 1  Montreal, PQ / Chesterville, ON    NaN   11            4           True
# 2  Montreal, PQ / Chesterville, ON    NaN  NaN            4           True
# 3  Montreal, PQ / Chesterville, ON  135.0  NaN            4          False
# 4  Montreal, PQ / Chesterville, ON    NaN  NaN            4          False

# %% [markdown]
# We can also change these values from the Boolean `True` and `False` to the binary values `1` and `0`.
#
# We can convert columns by using the code `.astype(“int64”)`.

# %%
titanic["under_18_binary"] = titanic["under_18_bool"].astype("int64")

titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000      0      0   24160  211.3375       B5        S
# 1   0.9167      1      2  113781  151.5500  C22 C26        S
# 2   2.0000      1      2  113781  151.5500  C22 C26        S
# 3  30.0000      1      2  113781  151.5500  C22 C26        S
# 4  25.0000      1      2  113781  151.5500  C22 C26        S
#
#                          home.dest   body boat  family_size  under_18_bool  \
# 0                     St Louis, MO    NaN    2            1          False
# 1  Montreal, PQ / Chesterville, ON    NaN   11            4           True
# 2  Montreal, PQ / Chesterville, ON    NaN  NaN            4           True
# 3  Montreal, PQ / Chesterville, ON  135.0  NaN            4          False
# 4  Montreal, PQ / Chesterville, ON    NaN  NaN            4          False
#
#    under_18_binary
# 0                0
# 1                1
# 2                1
# 3                0
# 4                0

# %% [markdown]
# We can also do this in one step when we create the column. We can wrap the first part of the code in brackets; like our order of operations in mathematics this tells Python which bit to do first.
#
# In the cell below we add the new column in one line, and then sort out the missing values in the next.

# %%
# Add the new column and change the type in one line

titanic["under_18_binary"] = (titanic["age"] < 18).astype("int64")
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0  29.0000      0      0   24160  211.3375       B5        S
# 1   0.9167      1      2  113781  151.5500  C22 C26        S
# 2   2.0000      1      2  113781  151.5500  C22 C26        S
# 3  30.0000      1      2  113781  151.5500  C22 C26        S
# 4  25.0000      1      2  113781  151.5500  C22 C26        S
#
#                          home.dest   body boat  family_size  under_18_bool  \
# 0                     St Louis, MO    NaN    2            1          False
# 1  Montreal, PQ / Chesterville, ON    NaN   11            4           True
# 2  Montreal, PQ / Chesterville, ON    NaN  NaN            4           True
# 3  Montreal, PQ / Chesterville, ON  135.0  NaN            4          False
# 4  Montreal, PQ / Chesterville, ON    NaN  NaN            4          False
#
#    under_18_binary
# 0                0
# 1                1
# 2                1
# 3                0
# 4                0

# %% [markdown]
# It’s important to note that where we have missing values – it will mark those as `False` (or 0).
#
# This could really affect our data analysis.
#
# We’ll look at one way of fixing this after the exercises.

# %%
titanic[titanic['age'].isnull()].head()
# Out:
#     pclass  survived                                               name  \
# 15       1         0                                Baumann, Mr. John D
# 37       1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40       1         0                          Brewe, Dr. Arthur Jackson
# 46       1         0                              Cairns, Mr. Alexander
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
#
#        sex  age  sibsp  parch    ticket     fare cabin embarked  \
# 15    male  NaN      0      0  PC 17318  25.9250   NaN        S
# 37    male  NaN      0      0    111427  26.5500   NaN        S
# 40    male  NaN      0      0    112379  39.6000   NaN        C
# 46    male  NaN      0      0    113798  31.0000   NaN        S
# 59  female  NaN      0      0     17770  27.7208   NaN        C
#
#            home.dest  body boat  family_size  under_18_bool  under_18_binary
# 15      New York, NY   NaN  NaN            1          False                0
# 37   Los Angeles, CA   NaN    9            1          False                0
# 40  Philadelphia, PA   NaN  NaN            1          False                0
# 46               NaN   NaN  NaN            1          False                0
# 59      New York, NY   NaN    5            1          False                0

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Exercise
#
# Create a new boolean column in the `animals` DataFrame called `fish_bool`.
#
# Use the `AnimalClass` column to find the values that are eqivalant to `Fish`.
#
# Remember when we're checking equivalency we need the `==` symbol.

# %%
# Exercise
animals[animals["AnimalClass"]== "Fish"  ]
# Out:
#     IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 962      129048101  30/07/2010 21:44     2010  2010/11  Special Service
# 964      129261101  31/07/2010 06:15     2010  2010/11  Special Service
#
#      PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 962        1.0             1.0                   260                   260.0
# 964        2.0             5.0                   260                  1300.0
#
#                     FinalDescription AnimalGroupParent          PropertyType  \
# 962  FISH IN DANGER OF DYING IN POND              Fish  Lake/pond/reservoir
# 964  FISH IN DISTRESS, HVPU REQUIRED              Fish  Lake/pond/reservoir
#
#     SpecialServiceTypeCategory  \
# 962    Other animal assistance
# 964    Other animal assistance
#
#                                     SpecialServiceType  Borough StnGroundName  \
# 962  Animal assistance involving livestock - Other ...   Sutton        Sutton
# 964  Animal assistance involving livestock - Other ...  Enfield       Enfield
#
#     AnimalClass  Code        London  attended
# 962        Fish  00BF  Inner London      True
# 964        Fish  00AK  Inner London      True

# %%
# %load ../solutions/chapter_4/new_bool_col.py
#Create a new boolean column in the `animals` DataFrame.
#Use the `AnimalClass` column to find the values that are eqivalant to `Fish`
#Call your new column `fish_bool`.

animals["fish_bool"] = animals["AnimalClass"] == "Fish"

# Test if it's worked with a filter
animals[animals['AnimalClass'] == "Fish"] 
#animals.head()
# Out:
#     IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 962      129048101  30/07/2010 21:44     2010  2010/11  Special Service
# 964      129261101  31/07/2010 06:15     2010  2010/11  Special Service
#
#      PumpCount  PumpHoursTotal  HourlyNominalCost(£)  IncidentNominalCost(£)  \
# 962        1.0             1.0                   260                   260.0
# 964        2.0             5.0                   260                  1300.0
#
#                     FinalDescription    ...              PropertyType  \
# 962  FISH IN DANGER OF DYING IN POND    ...      Lake/pond/reservoir
# 964  FISH IN DISTRESS, HVPU REQUIRED    ...      Lake/pond/reservoir
#
#     SpecialServiceTypeCategory  \
# 962    Other animal assistance
# 964    Other animal assistance
#
#                                     SpecialServiceType  Borough StnGroundName  \
# 962  Animal assistance involving livestock - Other ...   Sutton        Sutton
# 964  Animal assistance involving livestock - Other ...  Enfield       Enfield
#
#     AnimalClass  Code        London attended  fish_bool
# 962        Fish  00BF  Inner London     True       True
# 964        Fish  00AK  Inner London     True       True
#
# [2 rows x 21 columns]

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Extension exercise
#
# Convert `fish_bool` to be a numerical value.

# %%
# Exercise

# %%
# Solution - These cells contain answers for the exercises.
# Run once to reveal the code
# Run again to reveal the output

# %load ../solutions/chapter_4/fish_bool_numeric.py

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ** Important note: Booleans and Missing Values **
#
# Earlier we declared a boolean column that has `True` for under 18, and `False` for over 18.
#
# One issue with this method is that if an entry in the `age` column is a missing value (`NaN`) then it is classified as `False` here.
#
#
# While Pandas has done exactly as we asked (it does not meet the criteria so is `False`) we’re artificially inflating the number of adults in our two end columns.
#
# Statistically this isn’t right. There's 263 missing values in the `age` column - as we don’t know the passengers age; so we should preserve the missing data types rather than assume they're over 18 (as it currently does!)
#
# The cell below is filtering the `titanic` dataframe - showing the values that are null (using `.isnull()` ) in the `age` column.
#
# You can see that they show `False` in the `under_18` column.

# %%
# Create the "under_18" column again - in case it's not been run yet!
titanic["under_18_bool"] = titanic["age"] < 18

# Look at missing values in the age column
# Note that in the "under_18" column - they are True!

titanic[titanic['age'].isnull()].head()
# Out:
#     pclass  survived                                               name  \
# 15       1         0                                Baumann, Mr. John D
# 37       1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40       1         0                          Brewe, Dr. Arthur Jackson
# 46       1         0                              Cairns, Mr. Alexander
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
#
#        sex  age  sibsp  parch    ticket     fare cabin embarked  \
# 15    male  NaN      0      0  PC 17318  25.9250   NaN        S
# 37    male  NaN      0      0    111427  26.5500   NaN        S
# 40    male  NaN      0      0    112379  39.6000   NaN        C
# 46    male  NaN      0      0    113798  31.0000   NaN        S
# 59  female  NaN      0      0     17770  27.7208   NaN        C
#
#            home.dest  body boat  family_size  under_18_bool  under_18_binary
# 15      New York, NY   NaN  NaN            1          False                0
# 37   Los Angeles, CA   NaN    9            1          False                0
# 40  Philadelphia, PA   NaN  NaN            1          False                0
# 46               NaN   NaN  NaN            1          False                0
# 59      New York, NY   NaN    5            1          False                0

# %% [markdown]
# We’ll look at more ways to action missing values in chapter 6; but for now we can use `.loc[]` to fill in these values.
#
# We’ll also talk about `.loc[]` in chapter 5. Basically `.loc[]` can look up rows or columns based on either their index; or as we’re doing here a logical statement – like a filter statement.
#
# Here we’re using `.loc[]` to find rows where the `age` column has a null value; and updating our new column `under_18` to show null (`NaN`) too using the keyword `None`.

# %%
titanic.loc[titanic['age'].isnull(), 'under_18_bool'] = None

# %% [markdown]
# Now our `NaN` in `age` are also `NaN` values in `under_18` - as we can see if we run the cell below.

# %%
titanic[titanic['age'].isnull()].head()
# Out:
#     pclass  survived                                               name  \
# 15       1         0                                Baumann, Mr. John D
# 37       1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40       1         0                          Brewe, Dr. Arthur Jackson
# 46       1         0                              Cairns, Mr. Alexander
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
#
#        sex  age  sibsp  parch    ticket     fare cabin embarked  \
# 15    male  NaN      0      0  PC 17318  25.9250   NaN        S
# 37    male  NaN      0      0    111427  26.5500   NaN        S
# 40    male  NaN      0      0    112379  39.6000   NaN        C
# 46    male  NaN      0      0    113798  31.0000   NaN        S
# 59  female  NaN      0      0     17770  27.7208   NaN        C
#
#            home.dest  body boat  family_size  under_18_bool  under_18_binary
# 15      New York, NY   NaN  NaN            1            NaN                0
# 37   Los Angeles, CA   NaN    9            1            NaN                0
# 40  Philadelphia, PA   NaN  NaN            1            NaN                0
# 46               NaN   NaN  NaN            1            NaN                0
# 59      New York, NY   NaN    5            1            NaN                0

# %% [markdown]
# While we still have missing data in this column that we may want to deal with later (see chapter 6); at least our “under_18” column is now more accurate. It's really important we think about missing values whenever we perform operations using our data.

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Mapping New Values

# %% [markdown]
# We can also use `.map()` to map a dictionary to a column.
#
# This can be useful when we want to explain coded variables for other users; e.g. the column `port` has the values `S`, `C` and `Q`.  We can use `.map()` to give the full names of these ports.

# %%
titanic["port"] = titanic["embarked"].map({"S":"Southampton",
                                           "C":"Cherbourg", 
                                           "Q": "Queenstown (Cobh)"})

titanic.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked home.dest   body boat  family_size  \
# 1304    2665  14.4542   NaN        C       NaN  328.0  NaN            2
# 1305    2665  14.4542   NaN        C       NaN    NaN  NaN            2
# 1306    2656   7.2250   NaN        C       NaN  304.0  NaN            1
# 1307    2670   7.2250   NaN        C       NaN    NaN  NaN            1
# 1308  315082   7.8750   NaN        S       NaN    NaN  NaN            1
#
#       under_18_bool  under_18_binary         port
# 1304            1.0                1    Cherbourg
# 1305            NaN                0    Cherbourg
# 1306            0.0                0    Cherbourg
# 1307            0.0                0    Cherbourg
# 1308            0.0                0  Southampton

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Deleting columns

# %% [markdown]
# There are a few ways to remove or drop columns.
#
# Let's look at cat_dog again

# %%
cat_dog
# Out:
#               name animal  age constant_string  constant_float  constant_int
# 0  Catalie Portman    Cat    3          mammal             3.2             8
# 1     Pico de Gato    Cat    5          mammal             3.2             8
# 2        Chewbarka    Dog    1          mammal             3.2             8
# 3      JK Meowling    Cat    7          mammal             3.2             8
# 4               K9    Dog   11          mammal             3.2             8

# %% [markdown]
# We have the inbuilt python statement del ; here to delete the column constant_float from cat_dog DataFrame

# %%
del cat_dog["constant_float"]
cat_dog
# Out:
#               name animal  age constant_string  constant_int
# 0  Catalie Portman    Cat    3          mammal             8
# 1     Pico de Gato    Cat    5          mammal             8
# 2        Chewbarka    Dog    1          mammal             8
# 3      JK Meowling    Cat    7          mammal             8
# 4               K9    Dog   11          mammal             8

# %% [markdown]
# We can also use the `.drop()` method.
#
# For versions of Pandas below 0.21.0

# %%
cat_dog.drop(labels=["constant_string", "constant_int"], axis=1, inplace=True)
cat_dog

# If this cell doesn't work check your version using pd.__version__
# If greater than 0.21.0 use the code in the text below.
# Out:
#               name animal  age
# 0  Catalie Portman    Cat    3
# 1     Pico de Gato    Cat    5
# 2        Chewbarka    Dog    1
# 3      JK Meowling    Cat    7
# 4               K9    Dog   11

# %% [markdown]
# Here note:
#
# * I’m passing my column names as a list, as there’s more than one
# * `axis=1` tells Pandas that we want to delete columns
# * `inplace=True`  updates the original Dataframe
#
# This is a very good example of how packages can evolve over time.
#
# From version 0.21.0 of Pandas we don’t need to provide `axis = `  as it can detect if you’re dealing with columns or rows.
#
# If you have that version or later you can use
#
# ```python
# cat_dog.drop(columns = ["constant_string", "constant_int"], inplace = True)
#
# ```
#
# However most of us are using version 0.20.0 within ONS so I must still use the “old” syntax. The “old” syntax is backwards compatible; so my code below should work, even if you’re using a newer version of Pandas than I am.
#
#
# An additional option is to use square brackets to just return the columns we want to – we covered that earlier in this section.

# %% [markdown]
# [return to menu](#menu)

# %% [markdown]
# <a id='merge'></a>
# <hr style="width:100%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:1">

# %% [markdown]
# ## Merging Data

# %% [markdown]
# Let’s have a look at the two `joining_data`  DataFrames.
#
# In `joining_data1` we have the columns `name`, `animal` and `age`.
# In `joining_data2` we have the columns `name` and `vaccinated`.
#
# `Arf Vader` only appears in `joining_data1` and `Spiderpig` only appears in `joining_data2`. The remainder of the animals appear in both DataFrames.

# %%
joining_data1
# Out:
#               name animal  age
# 0  Catalie Portman    cat    3
# 1     Pico de Gato    cat    5
# 2        Chewbarka    dog    1
# 3      JK Meowling    cat    7
# 4               K9    cat   11
# 5        Arf Vader    dog    6

# %%
joining_data2
# Out:
#               name  vaccinated
# 0  Catalie Portman        True
# 1     Pico de Gato        True
# 2        Chewbarka       False
# 3      JK Meowling        True
# 4               K9       False
# 5        Spiderpig        True

# %% [markdown]
# These two DataFrames have a column in common that we could use to join them on - `name`.
#
# We can create a variety of joins. These are often best demonstrated with a Venn diagram.
#
# I’m going to say that `joining_data1` is my “left” DataFrame, and that `joining_data2` is my “right” DataFrame.
#
# For this I’m going to highlight the position of 3 animal names. As we mentioned earlier:
#
# * `Arf Vader` is only in `joining_data1`, our “left” DataFrame.
# * `Spiderpig` is only in `joining_data2`, our “right” DataFrame
# * `Catalie Portman` is in both `joining_data1` and `joining_data2` and will represent values in BOTH DataFrames.

# %% [markdown]
# !["examples of merge"](../images/pdmerge.png)

# %% [markdown]
# As you can see `left` and `right` merges take the data from that DataFrame and any matches from the opposite one.
#
# This means that in our `left`:
# * `Arf Vader` is included because he has data in the left DataFrame.
# * `Arf Vader` has missing values for `vaccinated`, as he isn’t in that DataFame
# * `Catalie Portman` has data in all columns, as she appears in both the left and right
# * `Spiderpig` doesn’t have any data. We’re only taking data from the left, and he’s only in the right.

# %% [markdown]
# Let’s look at how we do this left merge in code.
#
# We’re going to use `pd.merge()` and do a left join.

# %% [markdown]
# Hopefully the code is fairly self-explanatory:
#
# * `left =` is our left hand DataFrame
# * `right= ` is our right hand DataFrame
#
#
# * `how= ` is how we want to perform the join – other options are
#  * `right`
#  * `outer`
#  * `inner`  (default behaviour)
#
#
# * ` on= ` is the name of the column both DataFrames have in common.
#  * If we're joining on more than one column we can specify a list here.
#
#
# * ` indicator` set to `True` adds an additional column showing if the data was in the left_only, both or right_only as applicable.
#
# Note - Some code may read
#
# ``` python
#
# left_merge = joining_data1.merge(right=joining_data2,
#                                  how="left",
#                                  on="name",
# ```
#
# This performs exactly the same merge - just using the object `joining_data1` rather than specifying it inside the `pd.merge` method. How you write this code is personal preference.

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %%
left_merge = pd.merge(left = joining_data1,
                      right= joining_data2, 
                                 how="left",
                                 on="name",
                                 indicator=True)

left_merge

# %% [markdown]
# ## Exercise
#
# Using `marvel_left` and `marvel_right` perform an outer join using the column `name`

# %%
# Exercise

# %%
# %load ../solutions/chapter_4/join_exercise_1.py
# Using `marvel_left` and `marvel_right` perform an outer join using the column `name` 

marvel_outer = marvel_left.merge(right=marvel_right, 
                                 how="outer",
                                 on="year", 
                                 indicator=True)
marvel_outer
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-ad61eb53b177> in <module>()
#       5                                  how="outer",
#       6                                  on="year",
# ----> 7                                  indicator=True)
#       8 marvel_outer
#
# C:\Python36\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#    4818                      right_on=right_on, left_index=left_index,
#    4819                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 4820                      copy=copy, indicator=indicator)
#    4821
#    4822     def round(self, decimals=0, *args, **kwargs):
#
# C:\Python36\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      51                          right_on=right_on, left_index=left_index,
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 53                          copy=copy, indicator=indicator)
#      54     return op.get_result()
#      55
#
# C:\Python36\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     556         (self.left_join_keys,
#     557          self.right_join_keys,
# --> 558          self.join_names) = self._get_merge_keys()
#     559
#     560         # validate the merge keys dtypes. We may need to coerce
#
# C:\Python36\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     808                     if not is_rkey(rk):
#     809                         if rk is not None:
# --> 810                             right_keys.append(right[rk]._values)
#     811                         else:
#     812                             # work-around for merge_asof(right_index=True)
#
# C:\Python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Python36\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# C:\Python36\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# C:\Python36\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'year'

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Extension Exercise 1
#
# Using `marvel_left` and `marvel_right` perform a left join.
#
# Join on the column containing year.
#
# Note that the names of these columns may not be the same in both DataFrames.
#
# Use the help function to explore solutions to this.

# %%
# Exercise

# %%
# %load ../solutions/chapter_4/join_exercise_2.py
# Using `marvel_left` and `marvel_right` perform a left join.
# Join on the columns containing year data.
# Note that the names of these columns may not be the same in both DataFrames.
# Use the help function to explore solutions to this. 

marvel_left_merge = marvel_left.merge(right=marvel_right , 
                                      how="left",
                                      left_on="year",
                                      right_on="release_year",
                                      indicator=True)
marvel_left_merge.head()

# Notice here we use the paramater left_on to list the names of the columns
# in our left dataframe
# and right_on for the names of the columns in our right.
# Out:
#                 name_x  year month  worldwide_box_office               name_y  \
# 0             Iron Man  2008   May             585174222             Iron Man
# 1             Iron Man  2008   May             585174222  The Incredible Hulk
# 2  The Incredible Hulk  2008  June             263427551             Iron Man
# 3  The Incredible Hulk  2008  June             263427551  The Incredible Hulk
# 4           Iron Man 2  2010   May             623933331           Iron Man 2
#
#    release_year  score _merge
# 0          2008     93   both
# 1          2008     67   both
# 2          2008     93   both
# 3          2008     67   both
# 4          2010     73   both

# %% [markdown]
# Note here that maybe “year” is not the best joining column! We’re getting multiple joins for movies that have different names because we only need that “year” data to match.

# %% [markdown]
# <hr style="width:50%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.5">

# %% [markdown]
# ## Extension Exercise 2
#
# Modify the previous join to:
#
# Join on **BOTH** the column containing names and the column containing years.
#
# Note that the names of these columns may not be the same in both DataFrames.
#
# Use the help function to explore solutions to this.

# %%
# Exercise

# %%
# %load ../solutions/chapter_4/join_exercise_3.py
# Using `marvel_left` and `marvel_right` perform a left join.
# Join on BOTH name and year columns.
# Note that the names of these columns may not be the same in both DataFrames.
# Use the help function to explore solutions to this. 

marvel_left_merge = marvel_left.merge(right=marvel_right , 
                                      how="left" ,
                                      left_on=["name", "year"],
                                      right_on=["name", "release_year"],
                                      indicator=True)
marvel_left_merge.head()

# Notice here we use the paramater left_on to list the names of the columns
# in our left dataframe
# and right_on for the names of the columns in our right.

# As we're using multiple columns these are in lists.
# Out:
#                                  name  year month  worldwide_box_office  \
# 0                            Iron Man  2008   May             585174222
# 1                 The Incredible Hulk  2008  June             263427551
# 2                          Iron Man 2  2010   May             623933331
# 3                                Thor  2011   May             449326618
# 4  Captain America: The First Avenger  2011  July             370569774
#
#    release_year  score     _merge
# 0        2008.0   93.0       both
# 1        2008.0   67.0       both
# 2        2010.0   73.0       both
# 3           NaN    NaN  left_only
# 4        2011.0   79.0       both

# %% [markdown]
# This would be a great solution if we had a larger dataset.
#
# For example in 1998 there was a movie called “The Avengers”. It's not a marvel movie, and does not star Iron Man, but instead Uma Thurman and Ralph Fiennes as spys! By using the name and year we'd ensure a higher level of accuracy, being as specific as you can is good.

# %% [markdown]
# <hr style="width:75%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:0.75">

# %% [markdown]
# ### Union Merge
#
# We can also do what's known as `union` merges, which is implimented using `pd.concat()`.
#
# This is where we can add data on to the bottom of an existing dataFrame.
#
# For example we have some new animals to add on to `joining_data1`, these are contained in the `union_joined` DataFrame.

# %%
union_joined = pd.concat(objs=[joining_data1, union_join_data], ignore_index=True)
union_joined

# %% [markdown]
# We can see our new additions - `Andy Warhowl`, `Voldetort` and `Repecka` here now.
#
# Here we’re assigning the output to a new DataFrame – `union_joined`.
#
# Our parameters and arguments in `pd.conact()` are:
# * `objs= ` Our objects that we wish to concatenate – here as a list
# * `ignore_index= ` My new DataFrame will have it’s “own” index starting from 0. If I set this to `False` then I will have two things with an index of 0 – and I don’t want that!

# %% [markdown]
# As we’ve said there’s often many ways to do things in Python!
#
# `.append()` and `.join()` also exist for example – here’s a link with a lot more detail about joining together data. [Merge, Join, Concatenate and Compare]( https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)

# %% [markdown]
# [return to menu](#menu)

# %% [markdown]
# <a id='excel_files'></a>
# <hr style="width:100%;height:4px;border-width:0;color:gray;background-color:#003d59; opacity:1">

# %% [markdown]
# ## End of Chapter

# %% [markdown]
# In this chapter we’ve explored:
# * Exploring our Data
# * Sorting our Data
# * Selecting our Data
# * Filtering our Data
# * Creating new columns of Data
# * Merging Data
#
#
# You have completed chapter 4 of the Introduction to Python course. Please move on to chapter 5.

# %% [markdown]
# [return to menu](#menu)
